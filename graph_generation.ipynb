# %%
from bs4 import BeautifulSoup
import pandas as pd
import networkx as nx
import re
import os
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import write_dot
from tqdm.notebook import tqdm

# %%
RCDATA = "data/cos_course_data_raw.xml"

# %%
with open(RCDATA, 'r', encoding='utf-8') as cdata:
    s = "".join(cdata.readlines())
    tree = BeautifulSoup(s)

# %%
rows = []
for dep in tree.findAll("courses"):
    for course in dep.findAll("course"):
        rows.append({
            "code": getattr(course.find("code"), "string", None),
            "name": getattr(course.find("name"), "string", None),
            "credits": getattr(course.find("credits"), "string", None),
            "credit-structure": getattr(course.find("credit-structure"), "string", None),
            "pre-requisites": getattr(course.find("pre-requisites"), "string", None),
            "overlap": getattr(course.find("overlap"), "string", None),
            "department": dep.get("department"),
            "description": getattr(course.find("description"), "string", None)
        })
        
df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#      code                                               name credits  \
# 0  APL100                              Engineering Mechanics       4
# 1  APL101    Applied Mathematics in Engineering Applications       3
# 2  APL102  Introduction to Materials Science and Engineering       4
# 3  APL103                               Experimental Methods       4
# 4  APL104                                    Solid Mechanics       4
#
#   credit-structure pre-requisites         overlap  \
# 0            3-1-0           None            None
# 1            3-0-0           None            None
# 2            3-0-2           None            None
# 3            3-0-2           None            None
# 4            3-1-0         APL100  APL105, APL108
#
#                         department  \
# 0  Department of Applied Mechanics
# 1  Department of Applied Mechanics
# 2  Department of Applied Mechanics
# 3  Department of Applied Mechanics
# 4  Department of Applied Mechanics
#
#                                          description
# 0  Kinematics, Statics, Equations of Motion, Rigi...
# 1  ordinary Differential Equation: Second order o...
# 2  Structure of Solids: atomic and inter-atomic b...
# 3  Experimental Analysis: Types of measurements a...
# 4  Introduction, State of stress at a point, equa...

# %% [markdown]
# ## Odd/Even sem course offering check
#
# Go over each course and the odd course data lists, and check whether the course was offered in odd or even semesters. Do nothing if offered in both, but if not consistent with both, raise a conflict.

# %%
YEARS = ["2122", "2021", "1920"]
COURSES_OFFERED_PATH = "data/courses_offered_anon"
odd_sem = pd.read_csv(f"{COURSES_OFFERED_PATH}/1_2122.csv")
odd_sem.head()
# Out:
#    S.No                    Course Name Slot Name         Units Type  \
# 0     1                  MAJOR PROJECT         P  0.0-0.0-80.0  NaN
# 1     2                 DESIGN PROJECT         X  0.0-0.0-20.0  NaN
# 2     3  ENGG. MATHEMATICS & MECHANICS         F   3.0-0.0-0.0  NaN
# 3     4         APPLIED FLUID DYNAMICS         J   3.0-1.0-0.0  NaN
# 4     5                SOLID MECHANICS         E   3.0-0.0-0.0  NaN
#
#      Instructor             Instructor Email      Lecture Time Tutorial Time  \
# 0   EMIR BHATIA        divit70@am.iitd.ac.in               NaN           NaN
# 1  RASHA TALWAR       suhana55@am.iitd.ac.in               NaN           NaN
# 2   TAIMUR SAMI  shankarmiraya@am.iitd.ac.in  TThF 11:00-12:00           NaN
# 3   JIVIKA BERA   randhawaanay@am.iitd.ac.in   MTF 12:00-13:00           NaN
# 4  ISHITA GHOSE         cghosh@am.iitd.ac.in   TWF 10:00-11:00           NaN
#
#    Practical Time  Vacancy  Current Strength Course Code
# 0             NaN       60                 0      AMD895
# 1             NaN       60                25      AMD899
# 2             NaN       90                25      AML701
# 3             NaN       90                32      AML713
# 4             NaN       60                22      AML732

# %%
for year in YEARS:
    for i in [1,2]:
        sem_yr_data = pd.read_csv(f"{COURSES_OFFERED_PATH}/{i}_{year}.csv")
        sem_yr_data = sem_yr_data.rename(columns={'Course Code': 'code'})
        df = df.merge(sem_yr_data[['code','Slot Name', 'Vacancy', 'Current Strength']],on='code',how='left')
        df = df.rename(columns={'Slot Name': f"{i}_{year}_slot", 'Vacancy': f"{i}_{year}_vacancy", 'Current Strength': f"{i}_{year}_strength"})

df.head()
# Out:
#      code                                               name credits  \
# 0  APL100                              Engineering Mechanics       4
# 1  APL100                              Engineering Mechanics       4
# 2  APL100                              Engineering Mechanics       4
# 3  APL101    Applied Mathematics in Engineering Applications       3
# 4  APL102  Introduction to Materials Science and Engineering       4
#
#   credit-structure pre-requisites overlap                       department  \
# 0            3-1-0           None    None  Department of Applied Mechanics
# 1            3-1-0           None    None  Department of Applied Mechanics
# 2            3-1-0           None    None  Department of Applied Mechanics
# 3            3-0-0           None    None  Department of Applied Mechanics
# 4            3-0-2           None    None  Department of Applied Mechanics
#
#                                          description 1_2122_slot  \
# 0  Kinematics, Statics, Equations of Motion, Rigi...           A
# 1  Kinematics, Statics, Equations of Motion, Rigi...           A
# 2  Kinematics, Statics, Equations of Motion, Rigi...           A
# 3  ordinary Differential Equation: Second order o...           B
# 4  Structure of Solids: atomic and inter-atomic b...         NaN
#
#    1_2122_vacancy  ...  1_2021_strength 2_2021_slot  2_2021_vacancy  \
# 0           500.0  ...             24.0           A           600.0
# 1           500.0  ...             24.0           A           600.0
# 2           500.0  ...             24.0           A           600.0
# 3           200.0  ...              NaN         NaN             NaN
# 4             NaN  ...            371.0           E           225.0
#
#    2_2021_strength 1_1920_slot  1_1920_vacancy  1_1920_strength 2_1920_slot  \
# 0              0.0           A           500.0            589.0           A
# 1              0.0           A           500.0            589.0         SU1
# 2              0.0           A           500.0            589.0           X
# 3              NaN         NaN             NaN              NaN         NaN
# 4            149.0           E           350.0            307.0           E
#
#    2_1920_vacancy  2_1920_strength
# 0           250.0            568.0
# 1             0.0              0.0
# 2             0.0              0.0
# 3             NaN              NaN
# 4           300.0            134.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Analysis and Graph Generation
#
# Read in the Programme XML files, and generate dependency graphs for all programmes

# %%
PROGRAMMES_PATH = "data/course_plans"
DOTFILES_PATH = "data/dependencies"
PROGRAMMES = os.listdir(PROGRAMMES_PATH)

# %%
color_dict = ["gray", "lightblue", "green", "orange"]
def getCourseColor(course_data):
    colorCode = 0
    try:
        data = course_data.iloc[0]
        if str(data["1_2122_slot"]) != "nan" : colorCode +=1
        if str(data["2_2122_slot"]) != "nan" : colorCode +=2
    except Exception as error:
        pass
    return color_dict[colorCode]

# %%
# flag = True
for prog in tqdm(PROGRAMMES):
    if prog.startswith('.'):
        continue
    with open(f"{PROGRAMMES_PATH}/{prog}") as cdata:
        s = "".join(cdata.readlines())
        soup = BeautifulSoup(s)
    clist = []
    for course in soup.courses.dc.find_all("course"):
        clist.append(course.string)
    for course in soup.courses.pl.find_all("course"):
        clist.append(course.string)
        
    if soup.program.attrs['type'] == "5y":
        for course in soup.courses.pc.find_all("course"):
            clist.append(course.string)
            
    print(clist)

    G = nx.DiGraph()
    G.add_nodes_from(clist, style='filled')
    for course in clist:
        course_data = df.loc[df['code'] == course]
        if course_data.empty: # MTL782, 783 don't have course data/description/prereqs in CoS, wow bhaiya
            continue
        prereqs = course_data.iloc[0]['pre-requisites']
        prereqlist = [] if prereqs is None else re.findall(r'[A-Z]{3}[0-9]{3}', prereqs)
#       print(f"{course}: {prereqlist}")
        for pr in prereqlist:
            if pr not in G:
                G.add_node(pr)
            G.add_edge(pr, course)
                
    #     for node in G:
    #         if flag:
    #             flag = not flag
    # #             for ele in course_data:
    # #                 print(ele)

    #             hello = course_data
    #         course_data = df.loc[df['code'] == node]
    #         G.nodes[node]['fillcolor'] = getCourseColor(course_data)

    output_path = f'{DOTFILES_PATH}/{prog.split(".")[0]}.png'
    P = nx.nx_pydot.to_pydot(G)
    P.write_png(output_path, prog=r'C:\Users\Arush Bansal\anaconda3\Library\bin\graphviz/dot.exe')
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# ['APL101', 'APL102', 'APL103', 'APL104', 'APL106', 'APL203', 'APL205', 'APL206', 'APL207', 'AMP262', 'APL302', 'APL311', 'APL321', 'APL331', 'APL361', 'APL380', 'APL390', 'APL405', 'APL410', 'APD411', 'MTL107', 'COL206', 'ELL201']
# ['BBL131', 'BBL132', 'BBL133', 'BBL231', 'BBL331', 'BBP332', 'BBL431', 'BBL432', 'BBL433', 'BBL434', 'BBD451', 'BBL731', 'BBL732', 'BBL733', 'CLL122', 'CLL231', 'CLL251', 'CLL252', 'CLL261', 'CLP301', 'CLP302', 'APL102', 'CLL110', 'MTL102']
# ['CVL111', 'CVL121', 'CVP121', 'CVL141', 'CVL212', 'CVL222', 'CVP222', 'CVL242', 'CVP242', 'CVL243', 'CVP243', 'CVL244', 'CVL245', 'CVL261', 'CVP261', 'CVL281', 'CVP281', 'CVL282', 'CVL321', 'CVP321', 'CVL341', 'CVL342', 'CVP342', 'CVL381', 'CVD411', 'CVP441', 'APL107', 'APL108']
# ['CLL110', 'CLL111', 'CLL113', 'CLL121', 'CLL122', 'CLL141', 'CLL222', 'CLL231', 'CLL251', 'CLL252', 'CLL261', 'CLL271', 'CLP301', 'CLP302', 'CLP303', 'CLL331', 'CLL352', 'CLL361', 'CLL371', 'CLD411', 'APL102', 'CML103']
# ['CLL110', 'CLL111', 'CLL113', 'CLL121', 'CLL122', 'CLL141', 'CLL222', 'CLL231', 'CLL251', 'CLL252', 'CLL261', 'CLL271', 'CLP301', 'CLP302', 'CLP303', 'CLL331', 'CLL352', 'CLL361', 'CLL371', 'APL102', 'CML103', 'CLL703', 'CLL731', 'CLL733', 'CLD880', 'CLD881', 'CLD882']
# ['COL106', 'COL202', 'COL215', 'COL216', 'COL226', 'COP290', 'COL331', 'COL333', 'COL334', 'COL351', 'COL352', 'COL362', 'COL380', 'COD490', 'COD492', 'ELL205', 'MTL103', 'MTL104', 'MTL105', 'MTL106', 'PYL102', 'PYL103']
# ['COL106', 'COL202', 'COL215', 'COL216', 'COL226', 'COP290', 'COL331', 'COL333', 'COL334', 'COL351', 'COL352', 'COL362', 'COL380', 'ELL205', 'MTL103', 'MTL104', 'MTL105', 'MTL106', 'PYL102', 'PYL103', 'COL703', 'COL726', 'COD891', 'COD892', 'COD893']
# ['ELL201', 'ELL202', 'ELL203', 'ELP203', 'ELL205', 'ELL211', 'ELL212', 'ELP212', 'ELL225', 'ELP225', 'ELL302', 'ELP302', 'ELL303', 'ELP303', 'ELL304', 'ELL305', 'ELP305', 'ELL311', 'ELP311', 'ELD411', 'COL106', 'MTL106', 'MCL142', 'PYL102']
# ['ELL201', 'ELL202', 'ELL203', 'ELP203', 'ELL205', 'ELL225', 'ELP225', 'ELL231', 'ELL302', 'ELP302', 'ELL303', 'ELP303', 'ELL304', 'ELL305', 'ELP305', 'ELL332', 'ELP332', 'ELL363', 'ELL365', 'ELD431', 'COL106', 'MTL106', 'MCL142', 'PYL102']
# ['APL104', 'APL106', 'MCL111', 'MCL131', 'MCL140', 'MCL201', 'MCL211', 'MCL212', 'MCL231', 'MCP231', 'MCL241', 'MCL242', 'MCL261', 'MCP301', 'MCL311', 'MCP331', 'MCL361', 'MCP401', 'MCD411', 'MCL431', 'APL102', 'MTL107', 'MTL108']
# ['APL104', 'MCL111', 'MCL132', 'MCL133', 'MCL134', 'MCL135', 'MCL136', 'MCL141', 'MCL201', 'MCL211', 'MCL212', 'MCP232', 'MCL261', 'MCP261', 'MCL262', 'MCL311', 'MCL331', 'MCP332', 'MCL361', 'MCP361', 'MCD411', 'MCL431', 'APL102', 'MTL107', 'MTL108']
# ['MLL103', 'MLL105', 'MLL252', 'MLL202', 'MLL204', 'MLL206', 'MLL271', 'MLL253', 'MLL341', 'MLL211', 'MLL362', 'MLL402', 'MLL342', 'MLL364', 'MLS302', 'MLP372', 'MLP311', 'MLP441', 'MLL411', 'MLD401', 'MTL107', 'APL104', 'MTL108', 'CLL110']
# ['ELL305', 'ELP305', 'MTL102', 'MTL103', 'MTL104', 'MTL105', 'MTL106', 'MTL107', 'MTL122', 'MTL180', 'MTP290', 'MTL342', 'MTL390', 'MTD421', 'MTL411', 'MTL445', 'MTL458', 'MTL783', 'MTL712', 'COL106', 'ELL201', 'PYL102']
# ['ELL305', 'ELP305', 'MTL102', 'MTL103', 'MTL104', 'MTL105', 'MTL106', 'MTL107', 'MTL122', 'MTL180', 'MTP290', 'MTL342', 'MTL390', 'MTL411', 'MTL445', 'MTL458', 'MTL712', 'MTL782', 'MTL783', 'COL106', 'ELL201', 'PYL102', 'MTL766', 'MTL781', 'MTD851', 'MTD852', 'MTD853', 'MTD854']
# ['PYP111', 'PYL121', 'PYL122', 'PYL123', 'PYL125', 'PYL127', 'PYL202', 'PYL204', 'PYL205', 'PYL206', 'PYL208', 'PYL209', 'PYP212', 'PYP221', 'PYP222', 'PYD411', 'CML102', 'ELL201', 'ELL205', 'ESL350']
# ['TXL130', 'TXL111', 'TXL211', 'TXL212', 'TXP212', 'TXL221', 'TXP221', 'TXL222', 'TXP222', 'TXL231', 'TXP231', 'TXL232', 'TXP232', 'TXL241', 'TXP241', 'TXL242', 'TXP242', 'TXL361', 'TXP361', 'TXL371', 'TXL372', 'TXD401', 'APL102', 'APL103', 'APL105']
