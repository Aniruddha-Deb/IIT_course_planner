# %%
# COS = "Courses-of-Study_2020-2021.pdf"
# COS = "Courses-of-Study-2020-2021.pdf"
COS = R"Courses of Study 2023-24.pdf"

COURSE_DESCRIPTION_PAGE_FIRST = 178
COURSE_DESCRIPTION_PAGE_LAST = 417

PROGRAMME_PAGE_FIRST = 46
PROGRAMME_PAGE_LAST = 96

# %%
import fitz  # PyMuPDF
import re

# %%
COURSE_PATTERN = r"^[A-Z]{3}\d{3}"
CREDIT_PATTERN = r"^\d"
PREREQ_PATTERN = r"^Pre-requi"
OVERLAP_PATTERN = r"^[Oo]verlaps"

STANDARD_COS_PAGE_X1 = 49
STANDARD_COS_PAGE_X2 = 300
STANDARD_COS_PAGE_X3 = 596
STANDARD_COS_PAGE_Y1 = 84
STANDARD_COS_PAGE_Y2 = 790

# %%
def extract_text_by_coordinates(pdf_document, page_number, x1, y1, x2, y2):
    page = pdf_document[page_number - 1]
    rect = fitz.Rect(x1, y1, x2, y2)
    
    selected_text = page.get_text("text", clip=rect)
    return selected_text

def standard_cos_page_scraper(pdf_doc, page):
    x1, y1 = STANDARD_COS_PAGE_X1, STANDARD_COS_PAGE_Y1  # Starting coordinates of the rectangle
    x2, y2 = STANDARD_COS_PAGE_X2, STANDARD_COS_PAGE_Y2  # Ending coordinates of the rectangle
    x3, y3 = STANDARD_COS_PAGE_X2, STANDARD_COS_PAGE_Y1
    x4, y4 = STANDARD_COS_PAGE_X3, STANDARD_COS_PAGE_Y2
    left_side = extract_text_by_coordinates(pdf_doc, page, x1, y1, x2, y2)
    right_side = extract_text_by_coordinates(pdf_doc, page, x3, y3, x4, y4)
    return [left_side, right_side]


def scrape_courses_description():
    scraped_dataset = []
    
    first_page_i = COURSE_DESCRIPTION_PAGE_FIRST
    last_page_i = COURSE_DESCRIPTION_PAGE_LAST


    pdf_doc = fitz.open(COS)
    for page in range(first_page_i, last_page_i + 1):
        scraped_dataset.extend(standard_cos_page_scraper(pdf_doc, page))

    pdf_doc.close()
    
    return scraped_dataset

def attach_courses_description(scraped_dataset):
    for i in range(len(scraped_dataset)):
        data = scraped_dataset[i]
        if re.match(COURSE_PATTERN, data):
            scraped_dataset[i] = "\n" + data
        else :
            scraped_dataset[i] = " " + data
    return "".join(scraped_dataset)

def string_course_dataset_to_json(single_string_dataset):
    all_lines = single_string_dataset.split("\n")[1:]
    all_courses = []
    course = {}
    is_first_course = True
    for line in all_lines:
        if re.match(COURSE_PATTERN, line):
            if is_first_course: is_first_course = False
            else: all_courses.append(course)
            course = {
                "code" : line[:6],
                "name" : line[7:],
                "description" : "",
                "preReq" : "",
                "overLap" : "",
                "credits" : ""
            }
        elif re.match(CREDIT_PATTERN, line): course["credits"] = line
        elif re.match(PREREQ_PATTERN, line): course["preReq"] = line
        elif re.match(OVERLAP_PATTERN, line): course["overLap"] = line
        else: course["description"]  += line
    all_courses.append(course)

    return all_courses



def get_all_courses_description():
    scraped_dataset : list[str] = scrape_courses_description()
    single_string_dataset : str = attach_courses_description(scraped_dataset)
    courses_json_list : list[object] = string_course_dataset_to_json(single_string_dataset)
    return courses_json_list



# -------------------------------------------------------------------------------------------------------------
all_courses = get_all_courses_description()
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## TODO
# - modify the pre-req structure and credit structure
#
#
#
# #### THE EDGE CASES NOT YET HANDLED
# ##### COS 20-21
# - edge-case : page number 365
# - prereq wrong in HUL275
# - weird description in SBL724
# - multiline pre-req in SBL720, SBL708, SBL710
# - multiline course name in ASD882, and also there is a not allowed condition there in the name
# - multiline course anem in CRL725
# - Non-Credit Mandatory field in TXT800
# - HUL modifications

# %%
for ele in all_courses:
    if ele["code"] == "COL106":
        for a in ele:
            print(f"{a} :: {ele[a]}")
# Out:
# code :: COL106
# name :: Data Structures & Algorithms
# description :: Introduction to object-oriented programming through stacks queues and linked lists. Dictionaries; skip-lists, hashing, analysis of collision resolution techniques. Trees, traversals, binary search trees, optimal and average BSTs. Balanced BST: AVL Trees, 2-4 trees, red-black trees, B-trees. Tries and suffix trees. Priority queues and binary heaps. Sorting: merge, quick, radix, selection and heap sort, Graphs: Breadth first search and connected components. Depth first search in directed and undirected graphs. Disjkra’s algorithm, directed acyclic graphs and topological sort. Some geometric data-structures.
# preReq :: Pre-requisite(s): CoL100
# overLap ::
# credits :: 5 Credits (3-0-4)

# %% [markdown]
# Let the group of courses have a partial order (the dependency) and an equivalence relation (the overlaps)...
#
# No! We need boolean algebra for this.

# %%
for course in all_courses:
    print(course['code'], course['overLap'])
# Out:
# APL100
# APL101
# APL103
# APL104 overlaps with: APL105, APL108
# APL105 overlaps with: APL104, APL106, APL107, APL108
# APL106 overlaps with: APL107, APL105
# APL107 overlaps with: APL106, APL105
# APL108 overlaps with: APL104, APL105
# APL190
# APL203 overlaps with: MCL111, MCL731
# APL205
# APL206 overlaps with: MCL140
# APL207 overlaps with: CLL251, MCL242, ESL760
# APL300
# CHL231
# APL302 overlaps with: APL775
# APV303
# APL306 overlaps with: CVL759, MCL733
# APD310
# APL310
# APD311
# APL311 overlaps with: APL705, APL706
# APL321 overlaps with: APL720, CLL768, MCL813
# APL331
# APL340
# APL360
# APL361
# APL380
# APL390
# APL402
# APL405 overlaps with: ELL784, CoL341, CoL774
# APL410
# APL411
# APL412 overlaps with: MCL738
# APL415 overlaps with: APL835
# APL421
# APL422 overlaps with: APL720, CLL768, MCL813
# APL424
# APL431
# APL432
# APL433 overlaps with: APL831, CVL858
# APL434 overlaps with: CVL864
# APL435
# APL440
# APL450
# APL452
# APL491
# AML701
# APL701
# AML702
# APL702
# APL703
# AML704
# APL705
# AML706
# APL707 overlaps with: MTL746
# APL710
# APV710
# APL711
# AML713
# APL713
# AML714
# AML715
# APL715
# APL716
# APL720
# AML731
# AML732
# AML733
# APL734
# APL736
# APL737
# APL740
# APL744
# APL745
# APL746 overlaps with: ASL734, ASL823, ASL737
# APL747
# AML751
# APL753
# APL764
# APL765
# APL767
# APL771
# APL774
# APL775
# APL776
# AMP777
# AML791
# AML792
# AML793
# AML794
# AML795
# APL796
# APV779
# AMS801
# AMS802
# APL805
# AML731
# APD811
# AML811
# APD812
# AMD813
# AMD814
# APL815
# AML816
# AML820
# AML821
# APL821
# APL831
# AML832
# AML833
# AML834
# APL835
# AML836
# AML837
# AML838
# AML840
# AML841
# APL871
# AML872
# AML873
# APD895
# AMD897
# AMD899
# BBL131
# BBL132
# BBL133 overlaps with: CLL111
# BBL231
# BBL331
# BBP332
# BBL341
# BBL342
# BBL343
# BBV350
# BBD351
# BBL431
# BBL432
# BBL433
# BBL434
# BBL441
# BBL442
# BBL443
# BBL444
# BBL445
# BBL446
# BBL447
# BBD451
# BBD452
# BBL731
# BBL732
# BBL733
# BBL734
# BBL735
# BBL736
# BBL737
# BBL740
# BBL741
# BBL742
# BBL743
# BBL744
# BBL745
# BBL746
# BBL747
# BBL748
# BBL749
# BBL750
# BBL751
# BBL752
# BBL754
# BBL756
# BBL757
# BBV750
# BBL771 overlaps with: BBL131, BBL231, BBL830, SBL751
# BBL772 overlaps with: SBL701, MSL874
# BBL773
# BBL774
# BBL775
# BBL810
# BBL820
# BBL830
# BBP840
# BBL850
# CLL110
# CLL111
# CLL113 overlaps with: MTL107, MTP290, MTL445, CVL734, CoL726
# CLL121 overlaps with: MCL140, MCL141, MCL142
# CLL122
# CLL133
# CLL141
# CLL222
# CLL231 overlaps with: APL107, APL106, APL105
# CLL251 overlaps with: MCL242
# CLL252
# CLL261 overlaps with: MCL212, ELL225, ELL205
# CLL271 overlaps with: BEN150, BBL431, BBL731
# CLL296 overlaps with: PYL421
# CLP301
# CLP302
# CLP303
# CLL331
# CLL352
# CLL361
# CLL371
# CLL390
# CLL402 overlaps with: CLL703
# CLD411
# CLD412
# CLD413
# CLD414
# CLD415
# CLL475
# CLL477
# CLL701 overlaps with: CLL110, CLL113, MTL107, MTL445, CoL726
# CLL702 overlaps with: CLL121, CLL122, MCL140, MCL141, MCL142
# CLL703
# CLP704
# CLL705
# CLL706
# CLL707
# CLL720
# CLL721
# CLL722
# CLL723
# CLL724 overlaps with: CVL100, CVL212, CVL311, CVL312, BBL742
# CLL725
# CLL726
# CLL727 overlaps with: Basic concepts in heterogeneous catalysis, catalyst
# CLL728
# CLL729
# CLL730 overlaps with: SBV882, MCL442
# CLL731
# CLL732
# CLL733
# CLL734
# CLL735
# CLL736
# CLL742
# CLL743
# CLL760
# CLL761
# CLL762 overlaps with: APL703
# CLL766
# CLL767 overlaps with: MLL721, MLL719, TTL712
# CLL768 overlaps with: AML410, MEL807
# CLL769 overlaps with: APL410, APL720, MCL813
# CLL770 overlaps with: MCL826
# CLD771
# CLL771
# CLL772
# CLL773 overlaps with: PYL202
# CLL774 overlaps with: MCL315
# CLL775 overlaps with: PTL719
# CLL776
# CLL777
# CLL778 overlaps with: CYL669, SBL705, SBV885
# CLL779
# CLL780 overlaps with: BEL703, BEL820
# CLD781
# CLL781
# CLD782
# CLL782 overlaps with: MTL103, MTL625, MTL704, APL771, MCL742
# CLL783 overlaps with: ELL325, ELL723, BBL444
# CLL784
# CLL785 overlaps with: MTL720
# CLL786
# CLL787
# CLL788
# CLL789 overlaps with: ELL319, ELL720
# CLL791
# CLL792 overlaps with: MTL766, MAL719, SML802
# CLL793
# CLL794
# CLV796
# CLV797
# CLL798
# CLL799
# CLD880
# CLD881
# CLD882
# CLD895
# CML101
# CMP100
# CML102
# CML103
# CML511
# CMP511
# CMP512
# CML512
# CML513
# CML514
# CML515
# CML521
# CMP521
# CMP522
# CML522
# CML523
# CML524
# CML525
# CML526
# CMD631
# CML631
# CMD641
# CML661
# CML662
# CML663
# CML664
# CML665
# CML671
# CML672
# CML673
# CML674
# CML675
# CML681
# CML682
# CML683
# CML684
# CML691
# CML692
# CML693
# CML696
# CML670
# CML721
# CMP722
# CML723
# CML724
# CML726
# CMP728
# CML729
# CML731
# CML733
# CML734
# CML735
# CML737
# CML738
# CML739
# CML740
# CML741
# CML742
# CML743
# CML760
# CMD799
# CML801
# CMD806
# CMD807
# CVL100
# CVL111
# CVL121
# CVP121
# CVL141
# CVL212
# CVL222
# CVP222
# CVL242
# CVP242
# CVL243
# CVP243
# CVL244
# CVL245
# CVL261
# CVP261
# CVL281
# CVP281
# CVL282
# CVL284
# CVL311
# CVL312
# CVL313
# CVL321
# CVP321
# CVL341
# CVL342
# CVP342
# CVL344
# CVL361
# CVL381
# CVL382
# CVL383
# CVL384
# CVL385
# CVL386
# CVD411
# CVD412
# CVL421
# CVL422
# CVL423
# CVL424
# CVL431
# CVL432
# CVL433
# CVP434
# CVL435 overlaps with: CVL713
# CVL441
# CVP441
# CVL442
# CVL443
# CVL461 overlaps with: SML843
# CVL462
# CVL481
# CVL482
# CVL483
# CVP484
# CVL485
# CVL486
# CVD700
# CVL700
# CVP700
# CVL701
# CVL702
# CVL703
# CVL704
# CVL705
# CVL706
# CVL707
# CVL708
# CVL709
# CVD710
# CVL710
# CVP710
# CVL711
# CVL712
# CVL713
# CVL714
# CVL715
# CVL716
# CVD720
# CVS720
# CVL720
# CVD721
# CVL721
# CVL722
# CVL723
# CVL724
# CVL725
# CVD726
# CVL727
# CVL728
# CVL729
# CVL730
# CVP730
# CVS730
# CVL731
# CVP731
# CVL732
# CVL733
# CVL734
# CVL735
# CVL736
# CVL737
# CVL738
# CVL740
# CVL741
# CVL742
# CVL743
# CVL744
# CVL745
# CVL746
# CVL747
# CVL750
# CVD753
# CVS754
# CVD756
# CVL756
# CVP756
# CVS756
# CVD757
# CVL757
# CVD758
# CVL758
# CVL759
# CVL760
# CVL761
# CVL762
# CVL763
# CVL764
# CVL765
# CVL766
# CVL767
# CVL768
# CVL769
# CVL770
# CVC771
# CVD771
# CVL771
# CVP771
# CVS771
# CVC772
# CVD772
# CVL772
# CVP772
# CVD773
# CVL773
# CVL774
# CVL775
# CVD776
# CVL776
# CVS776
# CVD777
# CVL777
# CVD778
# CVL778
# CVL779
# CVD800
# CVL800
# CVP800
# CVS800
# CVD801
# CVL801
# CVD810
# CVL810
# CVP810
# CVS810
# CVD811
# CVL811
# CVL818
# CVL819
# CVL820
# CVP820
# CVL821
# CVP821
# CVL822
# CVL823
# CVL824
# CVL825
# CVL826
# CVL827
# CVL828
# CVL830
# CVS830
# CVD831
# CVL831
# CVD832
# CVL832
# CVV832
# CVL833
# CVL834
# CVL835
# CVL836
# CVL837
# CVL838
# CVL839
# CVL840
# CVL841
# CVL842
# CVL844
# CVL845
# CVL846
# CVL847
# CVL848
# CVL849
# CVL850
# CVL851
# CVS852
# CVD853
# CVD854
# CVL856
# CVL857
# CVL858
# CVL859
# CVL860
# CVL861
# CVL862
# CVL863
# CVL864
# CVL865
# CVL866
# CVL869
# CVL871
# CVL872
# CVL873
# CVL874
# CVL875
# CVL876
# CVD895
# COL100
# COL106
# COL202 overlaps with: MTL180
# COL215 overlaps with: ELL201
# COL216 overlaps with: ELL305
# COL226 overlaps with: CoL765
# COP290
# COD300
# COD310
# COR310
# COS310
# COP315
# COL331 overlaps with: ELL405
# COL333 overlaps with: CoL671, CoL770, ELL789
# COL334 overlaps with: ELL402
# COL341 overlaps with: ELL409, ELL784
# COL351 overlaps with: MTL342, CoL702
# COL352
# COL362
# COL380 overlaps with: CoL730
# COD492 overlaps with: CoD490
# COD494
# COL632
# COL633
# COL671
# COL672
# COP701
# COL702 overlaps with: CoL351
# COL703 overlaps with: CoL765 & CoL226
# COL707
# COL718
# COL719
# COL720
# COL722
# COL724
# COL726 overlaps with: MTL704
# COL727
# COL728
# COL729
# COL730
# COL731
# COL732
# COL733
# COL740
# COD745
# COP745
# COL750
# COL751
# COL752
# COL753
# COL754
# COL755
# COL756 overlaps with: MTL103, MTL704
# COL757
# COL758
# COL759 overlaps with: MTL730
# COL760
# COL761
# COL762
# COL764
# COL765 overlaps with: CoL226 & CoL703
# COL768
# COL770
# COL772 overlaps with: MTL785
# COL774 overlaps with: CoL341 ELL784, ELL888
# COL775 overlaps with: AIL721, APL745
# COL776
# COL777 overlaps with: AIL722, ELL729
# COL778
# ELL409
# COL780 overlaps with: ELL793
# COL781 overlaps with: ELL792
# COL783
# COL785
# COL786
# COL788 overlaps with: ELL782
# COS799
# COL812
# COL818
# COL819
# COP820
# COL821
# COL828
# COL829
# COL830
# COL831
# COL832
# COL851
# COL852
# COL860
# COL861
# COL862
# COL863
# COL864
# COL865
# COL866
# COL867
# COL868
# COL869
# COL870
# COL871
# COL872
# COL873
# COL874
# COL876
# COL886
# COV876
# COV877
# COV878
# COV879
# COV880
# COV881
# COV882
# COV883
# COV884
# COV885
# COV886
# COV887
# COV888
# COV889
# COD891
# COD892
# COP892
# COD893
# COD895
# DDL110
# DDL111
# DDL112
# DDP113
# DDP114
# DDL115
# DDL116
# DDL121
# DDL122
# DDL123
# DDL124
# DDL125
# DDD120
# DDL126
# DDL211
# DDL212
# DDL213
# DDL214
# DDL215
# XYW214
# DDP216
# DDL217
# DDL222
# DDL223
# DDL224
# DDL225
# DDL226
# DDR227
# DDL228
# DDD310
# DDL311
# DDL312
# DDL313
# DDL314
# DDL315
# DDD320
# DDL213
# DDL321
# DDR324
# DDD410
# DDL411
# DDR422
# DDD510
# DDD620
# DDL710
# DDP711
# DDP712
# DDL715
# DDL716
# DDP721
# DDP722
# DSL724
# DDL725
# DDL126
# DDP731
# DDL732
# DDL732
# DDL732
# DDL733
# DDP741
# DDL742
# DDL751
# DSL753
# DDR761
# DDR762
# DDL768
# DDR772
# DDL782
# DDD792
# DDD799
# DDR801
# DDL810
# DDR812
# DDL820
# DDV820
# DDR822
# DDD830
# DDR832
# DDL841
# DDR852
# DDR862
# DDD891
# DDD892
# DDL722
# DDL752
# ELL101
# ELP101
# ELL201
# ELL202
# ELL203
# ELP203
# ELL205
# ELL211 overlaps with: ELL732, ELL231, EPL336, EPL439 , PHL653,
# PHL704
# ELL212
# ELP212
# ELL225 overlaps with: MCL212, CLL261
# ELP225
# ELL231
# ELL301
# ELL302
# ELP302
# ELL303
# ELP303
# ELL304
# ELL305 overlaps with: CSL211
# ELP305
# ELS310
# ELL311
# ELP311
# ELL312
# ELL313
# ELL315
# ELL316
# ELL318 overlaps with: CSL316
# ELL319 overlaps with: ELL720
# ELS330
# ELL332
# ELP332
# ELL333 overlaps with: ELL721
# ELL334
# ELL335
# ELL363
# ELL365
# ELL400
# ELL401
# ELL402 overlaps with: ELL785, CoL334
# ELL405 overlaps with: CoL331, MTL458, ELL783
# ELL406
# ELL408
# ELL409 overlaps with: ELL784, ELL789, CoL341/CoL774
# ELL410
# ELD411
# ELL411 overlaps with: ELL712
# ELP411
# ELL417
# ELD431
# ELL431
# ELL433
# ELL436
# ELL437
# ELL440
# ELD450
# ELL450
# ELD451
# ELV451
# ELD452
# ELL452
# ELD453
# ELL453
# ELD454
# ELL454
# ELD455
# ELL455
# ELD456
# ELL456
# ELD457
# ELL457
# ELD458
# ELL458
# ELD459
# ELL459
# ELL460
# ELL700
# ELV700
# ELL701
# ELL702
# ELL703
# ELL704
# ELL705
# ELL706
# ELL707
# ELL708
# ELL709
# ELL710
# ELV710
# ELL711
# ELL712
# ELL713 overlaps with: CRL711
# ELL714
# ELL715
# ELL716
# ELL717
# ELL718
# ELP718
# ELL719
# ELP719
# ELL720 overlaps with: ELL319
# ELP720
# ELV720
# ELL721
# ELP721
# ELL722
# ELL723
# ELL724
# ELL725
# ELP725
# ELL727
# ELL728
# ELL729
# ELL730
# ELV730
# ELL731
# ELV731
# ELL732
# ELL733 overlaps with: CSL316
# ELL734
# ELV734
# ELL735
# ELL736
# ELP736
# ELL737
# ELL738 overlaps with: PYL795
# ELL739
# ELL740
# ELL741
# ELL742 overlaps with: CRL726
# ELL743 overlaps with: ELL739
# ELL744
# ELL745 overlaps with: ELL739
# ELL746
# ELL747
# ELL748
# ELL749
# ELL750
# ELV750
# ELL751
# ELL751
# ELL752
# ELV752
# ELL753
# ELV753
# ELL754
# ELL755
# ELL756
# ELL757
# ELL758
# ELL759
# ELL760
# ELL761
# ELL762
# ELL763
# ELL764
# ELL765
# ELL766
# ELL767
# ELL768
# ELL769
# ELL770
# ELL771
# ELL772
# ELL773
# ELL774
# ELL775
# ELL776
# ELL777
# ELL778
# ELL779
# ELD780
# ELL780
# ELP780
# ELV780
# ELL781
# ELP781
# ELV781
# ELL782
# ELP782
# ELL783
# ELL784 overlaps with: ELL409, CoL341, CoL774
# ELL785 overlaps with: CSL374, CSL672 (20%)
# ELL786
# ELL787
# ELL788
# ELL789 overlaps with: CoL333, CoL671, CoL770
# ELL790
# ELL791 overlaps with: MTL720
# ELL792
# JTD792
# ELL793 overlaps with: CoL780
# ELL794
# ELL795
# ELL796
# ELL797
# ELL798
# ELL799
# JVD799
# ELD800
# ELL800
# ELP800
# ELD801
# ELL801
# ELP801
# JTD801
# JVD811
# JVS801
# ELD802
# ELL802
# JVD812
# ELL803
# ELL804
# ELL805
# EEL806
# ELL806
# ELL807
# ELL808
# ELD810
# ELL810
# ELD811
# ELD812
# ELL812
# ELL813
# ELL814
# ELL815
# ELL816
# ELL817
# ELL818
# ELL819
# ELL820
# ELL821
# ELP821
# ELV821
# ELL822
# ELP822
# ELL823
# ELV823
# ELL824
# ELD830
# ELL830
# ELP830
# ELV830
# ELD831
# ELL831
# ELP831
# ELV831
# ELD832
# ELL832
# ELP832
# ELV832
# ELL833
# ELP833
# ELV833
# ELL834
# ELV834
# ELD850
# ELL850
# ELP850
# ELT850
# ELD851
# ELL851
# ELP851
# ELD852
# ELL852
# ELP852
# ELL853
# ELP853
# ELL854
# ELP854
# ELL855
# ELP855
# ELL856
# ELL857
# ELL858
# ELL859
# ELD870
# ELL870
# ELP870
# ELD871
# ELL871
# ELP871
# ELD872
# ELL872
# ELL873
# ELL874
# ELD880
# ELL880
# ELS880
# ELD881
# ELL881
# ELL882
# ELL883
# ELL884
# ELL885
# ELL886
# ELL887
# ELL888
# ELL889
# ELL890
# ELL891
# ELL892
# ELL893
# ELL894
# ELD895
# ELL895
# ELL896
# ELL897
# ELL898
# ELL899
# ESL100 overlaps with: Some overlap with ESL380, ESL714, ESL734,
# ESL875
# ESL200 overlaps with: Some overlap with ESL340, ESL360, ESL740,
# ESL753
# ESL220 overlaps with: Some overlap with PYL102, PYL306, PYL312,
# PYL125
# ESL260 overlaps with: Some overlap with ELL202
# ESP260 overlaps with: Some overlap with ESP713, ESP705
# ESL261 overlaps with: Some overlap with ELL201, ELL304
# ESL262 overlaps with: Some overlap with ELL401, ELL756
# ESL263 overlaps with: Some overlap with ELL231, ELL302, ELL332
# ESL280 overlaps with: Some overlap with ESL744, ESL870, ESL871,
# PYL305
# ESL300
# ESP300
# ESQ311
# ESL320 overlaps with: Some overlap with ESL360, ESL755, ESL852
# ESL330 overlaps with: Some overlap with ESL710
# ESL331 overlaps with: Some overlap with ESL768, CVL482
# ESL340 overlaps with: Some overlap with ESL740
# ESL341 overlaps with: Some overlap with ESL772, ESL773, ESL880
# ESL342 overlaps with: Some overlap with PYL705, CRL725, CLL723
# ESL350 overlaps with: ESL720
# ESL351 overlaps with: Some overlap with ESL711, ESL714, MCL343,
# MCL345
# ESL352 overlaps with: Some overlap with CLL723, ESL746
# ESL360 overlaps with: Some overlap with ESL730
# ESL361 overlaps with: Some overlap with ELL303, ELL363
# ESL370 overlaps with: Some overlap with ELL225, MCL212, CLL261
# ESL371 overlaps with: Some overlap with ESL743
# ESL263
# ESL372 overlaps with: Some overlap with ELL784, CoL303, CoL770,
# ELL789
# ESL373
# CLL121
# ESL374 overlaps with: Some overlap with ESL730, MCL730, PYL102,
# PYL651
# ESL375
# ESL376
# ESL377 overlaps with: Some overlap with ESL743, CLL782, CLL784,
# CLL785
# ESL380 overlaps with: Some overlap with ESL734, PYL302, PYL569
# ESL381 overlaps with: Some overlap with ESL737, PYL658
# ESL382 overlaps with: Some overlap with ESL737
# ESL390 overlaps with: Some overlap with ESL750, MCL760
# ESL400 overlaps with: Some overlap with ESL350, ESL750, ESL724,
# ESL714
# ELL766
# ESL410 overlaps with: Some overlap with ESL726, ESL732, ESL733,
# ESL735
# ESL420 overlaps with: Some overlap with ESL360, ESL730, ESL755,
# ELL743
# ESL450 overlaps with: Some overlap with ESL780, MCL345
# ESL480 overlaps with: Some overlap with ESL737
# ESL481 overlaps with: Some overlap with ESL744, ESL737, MLL341,
# PHL702
# ESL490 overlaps with: Some overlap with ESL340, ESL740, CVL862,
# ASL650
# ESL710
# ESL711
# ESL714
# ESL715
# ESL718
# ESL720
# ESL722
# ESL724
# ESL726
# ESL727
# ESL729
# ESL730
# ESL731
# ESL732
# ESL733
# ESL734
# ESL735
# ESL737
# ESL738
# ESL739
# ESL740
# ESL742
# ESL743
# ESL744
# ESL745
# ESL746
# ESL748
# ESL749
# ESL750
# ESL751
# ESL752
# ESL753
# ESL754
# ESL755
# ESL756
# ESL757
# ESL758
# ESL760
# ESL764
# ESL766
# ESL768
# ESL770
# ESL771
# ESL772
# ESL773
# ESL774
# ESL776
# ESL778
# ESL779
# ESL780
# ESL782
# ESL784
# ESL785
# ESL786
# ESL790
# ESL791
# ESL792
# ESL796
# ESL797
# ESL798
# ESL799
# ESL804
# ESL810
# ESL840
# ESL842
# ESL845
# ESL850
# ESL852
# ESL855
# ESL860
# ESL870
# ESL871
# ESL875
# ESL880
# ESL885
# ESN702
# ESN703
# ESN704
# ESN712
# ESN791
# ESP705
# ESP706
# ESP713
# ESP728
# ESV891
# ESD798
# ESD799
# ESD801
# ESD802
# ESD851
# ESD852
# ESS801
# ESS851
# JSD799
# JSD801
# JSD802
# JSS801
# HUL101
# HUP102
# HUL211
# HUL212
# HUL213
# HUL217
# HUL232
# HUL235
# HUL236
# HUL237
# HUL239
# HUL240
# HUL242
# HUL243
# HUL251
# HUL253
# HUL256
# HUL258
# HUL261
# HSL262
# HUL265
# HUL267
# HUL271
# HUL272
# HUL274
# HUL275
# HUL276
# HUL281
# HUL282
# HUL286
# HUL289
# HUL290
# HUL310
# HUL311
# HUL312
# HUL314
# HUL315
# HUL316
# HUL318
# HUL320
# HUL331
# HUL332
# HUL333
# HUL334
# HUL335
# HUL336
# HUL338
# HUL340
# HUL341
# HUL350
# HUL351
# HUL352
# HUL353
# HUL354
# HUL355
# HUL356
# HUL357
# HUL358
# HUL359
# HUL360
# HUL361
# HUL362
# HUL363
# HUL364
# HUL365
# HUL370
# HUL371
# HSL371
# HUL372
# HUL374
# HUL375
# HUL376
# HUL377
# HUL378
# HUL379
# HUL380
# HUL381
# HUL382
# HSL511
# HSP511
# HSL512
# HSL513
# HSL514
# HSL515
# HSL516
# HSP520
# HSL521
# HSS521
# HSL522
# HSL541
# HSL561
# HSL611
# HSP611
# HSL612
# HSP612
# HSL613
# HSL614
# HSP620
# HSL621
# HSL622
# HSL651
# HSL661
# HSP700
# HUD700
# HUL704
# HUL706
# HUL707
# HUL709
# HUL710
# HSL711
# HUL711
# HUL712
# HUL713
# HUL714
# HUL715
# HUL716
# HUL717
# HUL718
# HUL719
# HUL720
# HSL721
# HSL722
# HSL723
# HSL724
# HSL725
# HSL726
# HUL731
# HUL732
# HUL733
# HUL734
# HUL735
# HUL736
# HUL737
# HUL741
# HUL742
# HUL743
# HUL745
# HUL746
# HSL747
# HUL748
# HSL748
# HSL749
# HUL751
# HUL752
# HUL753
# HUL754
# HUL755
# HUL756
# HUL759
# HUL760
# HUL761
# HUL762
# HUL763
# HUL764
# HUL765
# HSL766
# HSL767
# HSL768
# HSL769
# HUL771
# HSV771
# HUL772
# HUL773
# HUL774
# HUL775
# HUL776
# HUL777
# HUL778
# HUL779
# HSL780
# HSL781
# HUL782
# HUL783
# HSL784
# HSL789
# HUL800
# HUL801
# HSL811
# HSL812
# HSL813
# HUL814
# HSL815
# HSL816
# HSL817
# HSL818
# HUL820
# HUL821
# HSL821
# HSL822
# HUL823
# HUL831
# HUL832
# HUL833
# HUL834
# HUL835
# HUL836
# HUL840
# HUL841
# HUL842
# HUL843
# HSL844
# HUL845
# HUL846
# HUL850
# HUL851
# HUL852
# HUL853
# HUL854
# HUL856
# HUL857
# HUL860
# HUL861
# HUL862
# HUL863
# HUL870
# HUL871
# HUL872
# HUL873
# HUL874
# HUL875
# HUL876 overlaps with: HSV771
# HUL877
# HUL878
# HUL879
# HUL880
# HUL881
# HUL882
# HUL883
# HUL884
# HUL885
# HUL886
# HUL888
# HUL889
# HUL891
# HUL893
# HUP102
# HUV731
# HUV734
# HUV735
# HUV747
# HUV748
# HUV773
# HUV774
# HUV781
# HUV886
# HUV887
# MSL301
# MSL302
# MSL303
# MSL304
# MSL305
# MSL306
# MSL307
# MSD308
# MSD309
# MSL310
# MSL401
# MSL402
# MSL403
# MSL404
# MSL405
# MSL406
# MSL407
# MSL408
# MSL409
# MSL700
# MSL701
# MSL702
# MSL703
# MSL704
# MSL705
# MSL706
# MSL707
# MSL708
# MSL709
# MSL710
# MSL711
# MSL712
# MSL713
# MSL714
# MSL715
# MSL716
# MSL717
# MSL718
# MSL719
# MSL720
# MSL721
# MSL722
# MSL723
# MSL724
# MSL725
# MSL726
# MSL727
# MSL728
# MSL729
# MSL730
# MSL731
# MSL733
# MSL734
# MSL735
# MSL740
# MSL745
# MSL760
# MSL780
# MSL781
# MSL782
# MSL783
# MSL784
# MSL799
# MDL800
# MDD801
# MDL801
# MDL802
# MDL803
# MDL804
# MDL805
# MSL801
# MSP801
# MSV801
# MDD802
# MSL802
# MSV802
# MDD803
# MSL803
# MSV803
# MSL804
# MSV804
# MSL805
# MSV805
# MDL806
# MSL806
# MSV806
# MSL807
# MSL808
# MSL809
# MSL810
# MSL811
# MSL812
# MSL813
# MSL814
# MSL815
# MSV815
# MSL816
# MSV816
# MSL817
# MSV817
# MSL818
# MSV818
# MSL819
# MSV819
# MSL820
# MSV820
# MSL821
# MSV821
# MSL822
# MSV822
# MSL823
# MSL824
# MSV824
# MSL825
# MSL826
# MSV826
# MSL827
# MSV827
# MSL828
# MSV828
# MSL829
# MSL830
# MSL831
# MSL832
# MSV832
# MSL833
# MSL834
# MSL835
# MSL836
# MSL839
# MSL840
# MSL841
# MSL842
# MSL843
# MSL844
# MSL845
# MSL846
# MSL847
# MSL848
# MSL849
# MSL850
# MSL851
# MSL852
# MSL853
# MSL854
# MSL855
# MSL856
# MSL858
# MSL859
# MSL861
# MSL862
# MSL863
# MSL864
# MSL865
# MSL866
# MSL867
# MSL868
# MSL869
# MSL870
# MSL871
# MSL872
# MSL873
# MSL874
# MSL875
# MSL876
# MSL877
# MSL878
# MSL879
# MSL880
# MSL881
# MSL882
# MSL883
# MSL884
# MSL885
# MSL886
# MSL887
# MSL888
# MSL889
# MSL890
# MSL891
# MSL892
# MSL895
# MSL896
# MSL897
# MSL898
# MSL899
# MST893
# MSC894
# MST894
# MLL100
# MLL102 overlaps with: MLL701
# MLL103
# MLL104 overlaps with: MLL701, CLL736, CML729, PYL707
# MLL181
# MLL202 overlaps with: MLL713
# MLL203
# MLL212
# MLL213
# MLL242 overlaps with: TXL110
# MLL251 overlaps with: MLL711
# MLL253 overlaps with: PYL102, PYL703, CML102
# MLL262
# MLL264
# MLS302
# MLL341
# MLP352
# MLL342
# MLL343
# MLL344
# MLL345 overlaps with: MLL729
# MLP354
# MLL361
# MLP362
# MLL363 overlaps with: MCL780
# MLL364 overlaps with: MCL135, MCL778
# MLL365 overlaps with: MCL133
# MLL366 overlaps with: MCL788
# MLL371
# MLL372 overlaps with: MLL712
# MLL452
# MLP473
# MLL701
# MLL702
# MLL703
# MLP704
# MLL712
# MLL713
# MLL714
# MLL715
# MLL716
# MLL717
# MLL718
# MLL719 overlaps with: MLL242, TXL711
# MLL720
# MLL721
# MLL722 overlaps with: MLL343
# MLL723 overlaps with: MLL104
# MLL724
# MLL725
# MLP709
# MLP728
# MLL727
# MLL729
# MLL730
# MLL731
# MLL732
# MLL733
# MLL734
# MLL735
# MLL736
# MLL737
# MLL738
# MLL739
# MLL740
# MLL741
# MLL742 overlaps with: MCL331
# MLL744
# MLL746
# MLL748
# CLL141
# MLL750
# ELL211
# MLL752
# MLL760
# MLN710
# MLV705
# MLV700
# PTP709
# PTP710
# MLS800
# MLV700
# MLD799
# MLD801
# MLD802
# MLD811
# MLD812
# MTL100
# MTL101
# MTL102 overlaps with: MTL260
# MTL103 overlaps with: MTL508, CLL782, MCL261
# MTL104 overlaps with: MTL502
# MTL105 overlaps with: MTL501
# MTL106 overlaps with: MTL108
# MTL107 overlaps with: MTL509, CLL113, CVL763
# MTL108 overlaps with: MTL106, MTL390
# MTL122 overlaps with: MTL503, MTL506
# MTL145
# MTL146
# MTL180 overlaps with: CoL202
# MTL260
# MTL265 overlaps with: CoL756
# MTL270 overlaps with: MTL510
# MTP290
# MTL342 overlaps with: CoL351
# MTD350
# MTL390 overlaps with: MTL108
# MTL411 overlaps with: MTL602
# MTL415 overlaps with: MTL765
# MTD421
# MTL445 overlaps with: MTL712, CLL113
# MTL458 overlaps with: CoL331, ELL405
# MTL501
# MTL502
# MTL503
# MTL504
# MTL505
# MTL506
# MTL507
# MTL508
# MTL509
# MTL510
# MTL601
# MTL602
# MTL603
# MTL625
# MTD701
# MTD702
# MTL704
# MTL712
# MTL717
# MTL720
# MTL725
# MTL728
# MTL729
# MTL730 overlaps with: CoL759
# MTL731
# MTL732 overlaps with: MCL363/MSL873
# MTL733
# MTL734
# MTL735 overlaps with: MTL145
# MTL736
# MTL737
# MTL738
# MTL739
# MTL741
# MTL742
# MTL743
# MTL744 overlaps with: ELL710
# MTL745
# MTL746
# MTL747
# MTL750 overlaps with: CoL106, CoL302
# MTL750
# MTL751
# MTL754 overlaps with: CoL781, ELL792
# MTL755
# MTL756 overlaps with: MTL856
# MTL757
# MTL760 overlaps with: CoL758
# MTL761
# MTL762
# MTL763
# MTL766
# MTL768 overlaps with: MTL776
# MTL773
# MTL776 overlaps with: MTL768, CoL751
# MTL780
# MTL781
# MTL782
# MTL783 overlaps with: CoL352
# MTL785 overlaps with: CoL772
# MTV791
# MTL792
# MTL793
# MTL794
# MTL795
# MTL796
# MTL797
# MTL799
# MTL843
# MTL851
# MTL854
# MTL855
# MTL856 overlaps with: MTL756
# MTL860
# MTL863
# MTL874
# MTL882
# MTL883
# MTL888
# MCP100
# MCP101
# MCL111
# MCL131 overlaps with: With three core courses of ME2 (30% each)
# MCL132 overlaps with: 30% with MCL131
# MCL133
# MCL134 overlaps with: MCL231
# MCL135
# MCL136
# MCL140
# MCL141 overlaps with: MCL140, MCL242 (50%), CLL110 (50%)
# MCL142 overlaps with: MCL140, MCL141, CLL121
# MCL201
# MCL211
# MCL212 overlaps with: 50-60% with ELL225 and CLL261
# MCL231 overlaps with: MCL134, MCL136
# MCP231 overlaps with: MCP232 (60%)
# MCP232 overlaps with: MCP231 (60%)
# MCL241 overlaps with: ESL714 (>50%)
# MCL242 overlaps with: CLL251
# MCL261
# MCP261
# MCL262
# MCP301
# MCL311 overlaps with: AML705, 706, 710 (course should be mutually
# MCL314 overlaps with: MEL733 (20%), MEL746 (50%), ITL 760 (60%)
# MCL318
# MCL321 overlaps with: MEL311 (10%),
# MCL322 overlaps with: MEL311 (10%)
# MCL330
# MCL331
# MCP331
# MCP332
# MCL334 overlaps with: 5% with MEL312
# MCL336
# MCL337
# MCL338 overlaps with: MEL749, EEL482
# MCL341
# MCL343
# MCL344 overlaps with: ESL850
# MCL345 overlaps with: <10% with PG I.C. Engine course
# MCL347 overlaps with: MCL441 (~20%)
# MCL348
# MCL350
# MCL361
# MCP361
# MCL363
# MCL364 overlaps with: MEL671
# MCL366
# MCL368
# MCL370
# MCL380
# MCV390
# MCP401
# MCD411
# MCD412
# MCL421 overlaps with: MEL736 (40% - Students should be allowed to
# MCL422
# MCL431
# MCL441
# MCL442
# MCL443 overlaps with: CLL722 (30%), CLL720 (10%), CLL721 (15%)
# MCL701
# MCL702
# MCL703
# MCL704
# MCL705
# MCL709
# MCL710
# MCL711 overlaps with: APL765 and MLL714
# MCL712
# MTL100
# MCL311
# MCL715
# MCL716
# MCL717
# MCL721
# MCL722
# MCL723
# MCL724
# MCL725
# MCL726
# MCL728
# MCL729
# MCL730
# MCL731
# MCL732
# MCL733
# MCL735
# MCL736
# MCL738
# MCL740
# MCL741
# MCL742
# MCL743
# MCL745
# MCL747
# MCL748
# MCL750
# MCL751
# MCL753
# MCL754
# MCL755
# MCL756
# MCL757
# MCL758
# MCL759
# MCL760
# MCL761
# MCL763
# MCL765
# MCL769
# MCL770
# MCL771
# MCL772
# MCL773
# MCL775
# MCL776
# MCL778
# MCL780
# MCL781
# MCL782
# MCL783
# MCL784
# MCL785
# MCL786
# MCL787
# MCL788
# MCP790
# MCL791
# MCL792
# MCL795
# MCL796
# MCL797
# MCL798
# MCL799
# MCD800
# MCD810
# MCD811
# MCL811
# MCD812
# MCL812
# MCL813
# MCL814
# MCL815
# MCL816
# MCL817
# MCL818
# MCL819
# MCL820
# MCL821
# MCL822
# MCL823
# MCL824
# MCL825
# MCL826
# MCS830
# MCD383
# MCD832
# MCL834
# MCL837
# MCL840
# MCL845
# MCL848
# MCL849
# MCV849
# MCD861
# MCD862
# MCL865
# MCL866
# MCD881
# MCD882
# MCD895
# PYL101
# PYP100
# PYL102
# PYL105
# PYP111
# PYL113
# PYL114
# PYL115
# PYL121
# PYL122
# PYL123
# PYL125
# PYL127
# PYL202
# PYL204
# PYL205
# PYL206
# PYL208
# PYL209
# PYP212
# PYP223
# PYP224
# PYP223
# PYP224
# PYL302
# PYL303
# PYL304
# PYL305
# PYL306
# PYL307
# PYL311
# PYL312
# PYL313
# PYL321
# PYL322
# PYL323
# PYL324
# PYL331
# PYL332
# PYD411
# PYL411
# PYD412
# PYL412
# PYL413
# PYD414
# PYL414
# PYV418
# PYV419
# PYL421
# PYL422
# PYL423
# PYV428
# PYV429
# PYL431
# PYL432
# PYL433
# PYL434
# PYL435
# PYV438
# PYV439
# PYL551
# PYL552
# PYL553
# PYL555
# PYL556
# PYL557
# PYL558
# PYL560
# PYD561
# PYP561
# PYD562
# PYP562
# PYL563
# PYP563
# PYL567
# PYL569
# PYL650
# PYL651
# PYL652
# PYL653
# PYL655
# PYL656
# PYL657
# PYD658
# PYL658
# PYL659
# PYL701
# PYP701
# PYL702
# PYP702
# PYL703
# PYL704
# PYL705
# PYL707
# PYL711 overlaps with: APL340, ESL300, AML836
# PYL723
# PYL724
# PYL725
# PYL726
# PYL727
# PYL728
# PYL729
# PYL739
# PYL740
# PYL741
# PYL742 overlaps with : PYL332
# PYL743
# PYL744 overlaps with : PYL433
# PYL745
# PYL746
# PYL747
# PYL748
# PYL749
# PYL750
# PYL125
# PYL751
# PYL752
# PYL753
# PYL755
# PYL756
# PYL757 overlaps with: PYL748
# PYL758
# PYL759
# PYL760
# PYL761
# PYP761
# PYL762
# PYP762
# PYP763
# PYP764
# PYL770 overlaps with : PYL412
# PYL771
# PYL772
# PYL780
# PYL790
# JOP791
# PYL791 overlaps with : PYL413 and PYL650
# JOP792
# PYL792
# JOL793
# PYL793 overlaps with : PYL312
# JOL794
# JOS795
# PYL795 overlaps with : PYL115, PYL311, PYL560 and PYL655
# JOV796
# PYL800
# JOD801
# JOD802
# PYD801
# PYD802
# PYD851
# PYD852
# PYS855
# PYL858
# PYL879
# PYV881
# PYV882
# PYD883
# PYL891
# PYL892
# TXL130
# TXL111
# TXL211
# TXL212
# TXP212
# TXL221
# TXP221
# TXL222
# TXP222
# TXL231
# TXP231
# TXL232
# TXP232
# TXL241
# TXP241
# TXL242
# TXP242
# TXD301
# TXR301
# TXS301
# TXL321
# TXL331
# TXL361
# TXP361
# TXL371
# TXL372
# TXL381
# TXL382
# TXD401
# TXD402
# TXL601
# TXL700
# TXV701
# TXV702
# TXV703
# TXV704
# TXV705
# TXV706
# TXV707
# TXL710
# TXL711
# TXP711
# TXL712
# TXP712
# TXL713
# TXL714
# TXL715
# TXP716
# TXL719
# TXL721
# TXL722
# TXL724
# TXL725
# TXP725
# TXL731
# TXL732
# TXL734
# TXL740
# TXL741
# TXL747
# TXL748
# TXL750
# TXL751
# TXS751
# TXL752
# TXR752
# TXL753
# TXL755
# TXL756
# TXP761
# TXL766
# TXL771
# TXL772
# TXL773
# TXL774
# TXL775
# TXL777
# TXL780
# TXL781
# TXL782
# TXL783
# TXL784
# TXL785
# TXL786
# TXL242
# TXT800
# TXD801
# TXD802
# TXD803
# TXD804
# TXD805
# TXD806
# TXS805
# TXS806
# TXL807
# TXD809
# CRL601
# CRL611
# CRL621
# CRL702
# CRL704
# CRL706
# CRL707
# CRL708
# CRL709
# CRL711
# CRL712
# CRL715
# CRL722
# CRL724
# CRL725
# CRL726
# CRL727
# CRL729
# CRL731
# CRL732
# CRL733
# CRL734
# CRP718
# CRP723
# CRS735
# CRV741
# CRV742
# CRV743
# CRD802
# CRD811
# CRD812
# CRD814
# ASL320
# ASL340
# ASL350
# ASL360
# ASL370
# ASL375
# ASL380
# ASL385
# ASD390
# ASL730
# ASP731
# ASL732
# ASL733
# ASL734
# ASL735
# ASL736
# ASL737
# ASL738
# ASL750
# ASL751
# ASL752
# ASL753
# ASL754
# ASL755
# ASL756
# ASL757
# ASL758
# ASL759
# ASL760
# ASL761
# ASL762
# ASL763
# ASL765
# ASS800
# ASP820
# ASL821
# ASL822
# ASL823
# ASL824
# ASP825
# ASL826
# ASL827
# ASL851
# ASL852
# ASL853
# ASL854
# ASP855
# ASL856
# ASV862
# ASV863
# ASV864
# ASV865
# ASV866
# ASP867
# ASP868
# ASC869
# ASD881
# ASD882
# ASV892 overlaps with: ASL760
# CTP702
# ITL702
# CTL703
# ITL703
# CTP704
# CTL704
# CTL705
# ITL705
# CTL707
# CTL709
# ITL709
# ITL710
# CTL711
# ITL711
# CTL713
# ITL714
# CTL715
# ITL717
# CTL719
# CTL725
# CTL727
# CTL729
# ITL730
# CTL731
# CTL731 overlaps with: MCL345, MCL721, ESL780, ESL785
# CTL735
# ITL740
# ITL752
# ITL760
# ITL810
# JID800
# JIS800
# JID801
# CTD802
# JID802
# CTD895
# BML300
# BML330
# BML401
# BML700
# BMV700
# BMV701
# BMV702
# BMV703
# BMV704
# BVQ706
# BML710
# BML713
# BML720
# BML737
# BML738
# MEL707
# MSL892
# BML740
# BML741
# BMD742
# BML743
# BMP743
# BML750
# BML760
# BML770
# BML771
# BML772
# BML774
# BML780
# BML781
# BML790
# BML800
# BMD801
# BMD802
# BML810
# BML815
# BML820
# BML830
# BMV840
# BML850
# BML860
# BMV870
# BML880
# VEL700
# VEL710
# VEV731
# VEV732
# VEV733
# VEV734
# VEV735
# VEV736
# VEV737
# VEV738
# VEV739
# VEV740
# VEV741
# VEV742
# VED750
# RDL700
# RDL701
# RDL702
# RDL705
# RDL710
# RDL722
# RDL724
# RDL725
# RDL726
# RDL727
# RDL728
# RDL730
# RDL735
# RDL740
# RDL745
# RDD750
# RDP750
# RDL760
# RDL761
# RDL770
# RDL771
# RDL780
# RDL801
# RDL803
# RDL807
# DSL601
# DSL603
# DSP703
# DSP704
# DSP705
# DSL711
# DSL712
# DSL714
# DSS720
# DSL722
# DSL731
# DSL733
# DSL734
# DSL737
# DSL740
# DSL742
# DSD801
# DSD802
# DSL811
# DSC812
# DSL814
# DSL815
# TRL700
# TRL701
# TRL702
# OPS310
# OPL700
# TRV751
# TRV754
# OPD710
# SIL761
# SIL763
# SIL765
# SIL769
# SIL801
# SIL802
# SIV813
# SIV851
# SIL861
# SIV861
# SIV864
# SIV871
# SID880
# SIV889
# SID890
# SIV895
# AIL701 overlaps with: MTL101, MTL104, MTL103, MTL106, MTL108,
# MTL265
# MCL761
# AIP701
# AID710
# AIS710
# AIL711 overlaps with: MTL704, CLL782
# AIL712 overlaps with: MTL712
# AIL721 overlaps with: CoL775 approx. 80%. APL745 approx. 40%.
# AIL722 overlaps with: ELL729 approx. 50 %. [CoL 333, CoL341,
# AIL723
# AIL741
# AIL742
# AIL801 overlaps with: MTL801
# AIL821
# AIL841
# AIL861
# AIL862
# AIV790
# SBL100
# SBP200
# SBL201
# SBD301
# SBL701
# SBL702
# SBL703
# SBL704
# SBL705
# SBL706
# SBL707
# SBL708
# SBL709
# SBL710
# SBL711
# SBL712
# BEL311
# SBL713
# SBL714
# SBL720
# SBL721
# SBL722
# SBL723
# SBL724
# SBL725
# SBL726
# SBL727
# SBL728
# SBL729
# SBL750
# SBV750
# SBL751
# SBC795
# SBC796
# SBS800
# SBL801
# SBL802
# SBP810
# SBV881
# SBV882
# SBV883
# SBV884
# SBV885
# SBV886
# SBV887
# SBV888
# SBV889
# SBV890
# SBV891
# SBV892
# SBV893
# SBV894
# SBD895
# SBV895
# SBV896
# SBV897
# SBV898
# SBV899
# BSP710
# BSD895
# SPV399
# SPL701
# SPL702
# SPL703 overlaps with: HuL709/814, HuV781, MSL709
# SPL704
# SPL705
# SPL706
# SPL707
# SPL708 overlaps with: MSL721, HuL315/HuL719
# SPL709
# SPL711
# SPL712 overlaps with: HuL736
# SPL720
# SPL721
# SPL722
# SPL730
# SPL740
# SPL741
# SPL750
# SPV791
# SPV792
# SPV793
# SPV794
# SPV795
# SPV796
# SPV797
# SPV798
# SPV799
# SPL810
# SPD881
# SPD882

# %%
class ProgrammeInformationClass:
    def __init__(self):
        self.insti_core = {
            "BS": 0,
            "BS_list": [],
            "EAS": 0,
            "EAS_list": [],
            "HuSS": 0,
        }
        self.programme_linked = 0
        self.departmental = {
            "core": 0,
            "core_list": [],
            "elective": 0,
            "elective_list": 0,
        }
        self.OC = 0
        self.total_graded = 0
        self.non_graded = 0
        self.suggested_OEC = []
        
    def __getitem__(self, key):
        # Implement __getitem__ to access attributes using square brackets
        if hasattr(self, key):
            return getattr(self, key)
        else:
            raise KeyError(f"'{type(self).__name__}' object has no attribute '{key}'")

# %%
# def data_modifier(course_scrapped_body):
course_1_body = course_body.split("\n")
programmeInfo = ProgrammeInformationClass()
print(programmeInfo)
print(course_1_body)
saveNextNumber = False
isCourseArea = False
currProperty = ""
for string in course_1_body:
    string = string.strip()
    if string == "": continue
    elif re.search(r"\(BS\)", string): 
        currProperty = "BS"
        saveNextNumber = True
    elif re.serarch(re"\(EAS\)", string):
        currProperty = 
    elif ""
# Out:
#   File "C:\Users\ARUSHB~1\AppData\Local\Temp/ipykernel_15008/2491001320.py", line 15
#     elif re.serarch(re"\(EAS\)", string):
#                       ^
# SyntaxError: invalid syntax

# %%
def scrape_course_header(pdf_doc, page_i):
    X1, X2 = 49, 596
    Y1, Y2 = 0, 84
    return extract_text_by_coordinates(pdf_doc, page_i, X1, Y1, X2, Y2).split("\n")

def is_course_table_page(pdf_doc, page_i):
    X1, X2 = 526, 596
    Y1, Y2 = 60, 200
    extractedText = extract_text_by_coordinates(pdf_doc, page_i, X1, Y1, X2, Y2)
    return "total" in extractedText.lower()
    
def get_all_programme_details():
    FIRST_PAGE_I = PROGRAMME_PAGE_FIRST
    LAST_PAGE_I = PROGRAMME_PAGE_LAST

    pdf_doc = fitz.open(COS)
    all_courses = []
    curr_course = {
        "header" : "",
        "body" : []
    }
    prev_table_page = True
    for page_i in range(FIRST_PAGE_I, LAST_PAGE_I + 1):
#         print(page_i)
        if is_course_table_page(pdf_doc, page_i):
            temp = "\n".join(curr_course["body"])
            curr_course['body'] = list(map(lambda x : x.strip(), temp.split('\n')))
            # curr_course["body_joined"] = 
#             print(curr_course["all_data_joined"], 'yu')
            # del curr_course["body"]
            all_courses.append(curr_course)
            curr_course = {
                "header" : "",
                "body" : []
            }
            prev_table_page = True
            continue
        if prev_table_page:
            prev_table_page = False
            curr_course["header"] = scrape_course_header(pdf_doc, page_i)
#             print("course header : ", curr_course["header"])
        curr_course["body"] += standard_cos_page_scraper(pdf_doc, page_i)
    pdf_doc.close()
    print(len(all_courses))
    return all_courses
#     for ele in all_courses:
#         print(ele["header"])
#     for course in all_courses:
#         print(course["header"])
#     print(curr_course)
#     print("------------------------------------------------------------")
#     print(all_courses[0]["header"])
#     return all_courses[0]["all_data_joined"]
#     for programme in all_courses:
#         programme[] = refactorCourseBody(programme)
#     return all_courses
    
all_courses = get_all_programme_details()
# Out:
# 18

# %% [markdown]
# ### Ignored Stuff in the programme code
#
# - the some starred coordinates, we will need to add these as additional comments(couldn't handle this with code because each * / ** / ***  represents has different things attached to it). Although later we could automate the additional comments and also show the courses other than this which have the same star in the programme

# %%
for course in all_courses:
    print('\n'.join(course['body'][:64]))
# Out:
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
# 12.5
# Departmental Courses
# Departmental Core
# 65.5
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 158
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# MCP101 Product Realization through Manufacturing
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 11
# Departmental Courses
# Departmental Core
#
# 69
# Departmental Electives
#
# 10
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 158
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
#
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 7
# Departmental Courses
# Departmental Core
#
# 67
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 154
# Non Graded Units
#
# 11
# Institute Core: Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# The overall Credit Structure
# Course Category
# Credits
# B.Tech. Part
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 7
# Departmental Courses
# Departmental Core
#
# 63
# Departmental Electives
#
# 09
# Open Category Courses
#
# 3
# Total B.Tech. Credit Requirement
# 140
# Non Graded Units
#
# 11
# M.Tech. Part
# Programme Core Courses
#
# 33
# Programme Elective Courses
#
# 12
# Open Elective
#
# 3
# Total M.Tech. Credit Requirement
#
# 48
#
# Grand Total Credit Requirement
# 188
# Institute Core: Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 10
# Departmental Courses
# Departmental Core
#
# 66
# Departmental Electives
#
# 14
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 158
# Non Graded Units
#
# 11
# Institute Core: Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 14
# Departmental Courses
# Departmental Core
#
# 55
# Departmental Electives
#
# 11
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 148
# Non Graded Units
#
# 11
# Institute Core: Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# CVL100 Environmental Science
# 2 0 0 2
# COL100 Introduction to Computer Science
# 3 0 2 4
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 14
# Departmental Courses
# Departmental Core
#
# 49
# Departmental Electives
#
# 11
# Open Category Courses
#
# 10
# Total B.Tech. Credit Requirement
# 142
# Non Graded Units
#
# 11
# M. Tech. Part
# Programme Core Courses
#
# 32
# Programme Elective Courses
#
# 14
# Total M.Tech. Credit Requirement
#
# 46
# Grand Total Credit Requirement
# 188
# Institute Core: Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Engineering Arts and Science (EAS)
#
# 02
# Graded Units
# 149
# Programme-linked Courses
#
# 15
# Departmental Courses
# Departmental Core
# 123
# Departmental Electives
#
# 15
# Open Category Courses
#
# 09
# Total Graded Credit requirement
# 158
# Non Graded Units
#
# 09
# Institute Core: Engineering Arts and Sciences
# CVL100 Environmental Science
# 2 0 0 2
# Total Credits
#
#
#
# 02
# Non Graded Units
# NEN100 Professional Ethics and Social
# 0 0 1 0.5
# Responsibility-1
# NLN100 Language and Writing Skills-1
# 0 0 2 1
# NEN101 Professional Ethics and Social
# 0 0 1 0.5
# Responsibility-2
# NLN101 Language and Writing Skills-2
# 0 0 2 1
# DSR227 Social Immersion
# 0 0 4 2
# DSR324 Industry Internship
# 0 0 4 2
# DSR422 Design Degree Show
# 0 0 4 2
# Departmental Core
# DDL110 Understanding Design and Design Movements 2 0 2 3
# DDL111 Visualization Techniques
# 1 0 4 3
# DDL112 Design Process
# 1 0 2 2
# DDP113 Computer Aided Visualization
# 0.5 0  3  2
# DDP114 Materials & Processes for Model Making
# 0 0 4 2
# DDL115 Design Thinking & Design Critique
# 1 0 2 2
# DDL116 Fundamentals of Design
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 15
# Departmental Courses
# Departmental Core
#
# 60
# Departmental Electives
#
# 10
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 153
# Non Graded Units
#
# 11
# Institute Core: Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 15
# Departmental Courses
# Departmental Core
#
# 60
# Departmental Electives
#
# 10
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 152
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 12
# Departmental Courses
# Departmental Core
#
# 67
# Departmental Electives
#
# 10
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 157
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3  1  0  4
# CMP100 Chemistry Laboratory
# 0  0  4  2
# MTL100 Calculus
# 3  1 0  4
# MTL101 Linear Algebra and Differential Equations
# 3  1  0  4
# PYL101 Electromagnetism & Quantum Mechanics
# 3  1  0  4
# PYP100 Physics Laboratory
# 0  0  4  2
# SBL100 Introductory Biology for Engineers
# 3  0  2  4
# Total Credits
#
#
#
# 24
# Programme-Linked Basic / Engineering Arts / Sciences Core
# MCL140 Engineering Thermodynamics
# 3  1  0  4
# MCL242 Heat Transfer
# 3  1  0  4
# MLL100 Introduction to Materials Science and Engg.
# 3  0  2  4
# Total Credits
#
#
#
# 12
# Institute Core: Engineering Arts and Sciences
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 11
# Departmental Courses
# Departmental Core
#
# 64
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 155
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 11
# Departmental Courses
# Departmental Core
#
# 64
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 155
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 11
# Departmental Courses
# Departmental Core
#
# 66
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 157
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
# 12.5
# Departmental Courses
# Departmental Core
# 63.5
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 156
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab)
# 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# MCP101 Product Realization through Manufacturing
# 0 0 4 2
# Total Credits
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
# 12.5
# Departmental Courses
# Departmental Core
# 59.5
# Departmental Electives
#
# 6
# Open Category Courses
#
# 12
# Total B.Tech. Credit requirement
# 148
# Non Graded Units
#
# 11
# M.Tech. Part
# Programme Core Courses
#
# 24
# Programme Electives Courses
#
# 18
# Total M.Tech. Requirement
#
# 42
# Total Graded Requirement
# 190
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
# 14.5
# Departmental Courses
# Departmental Core
#
# 58
# Departmental Electives
#
# 12
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 152.5
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab) 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# MCP101 Product Realization through Manufacturing 0 0 4 2
# Total Credits
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
#
# 12
# Departmental Courses
# Departmental Core
#
# 52
# Departmental Electives
#
# 16
# Open Category Courses
#
# 10
# Total Graded Credit requirement
# 148
# Non Graded Units
#
# 11
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab) 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# MCP101 Product Realization through Manufacturing 0 0 4 2

# %%
print('\n'.join(all_courses[15]['body']))
# Out:
# The overall Credit Structure
# Course Category
# Credits
# Institute Core Courses
# Basic Sciences (BS)
#
# 24
# Engineering Arts and Science (EAS)
#
# 19
# Humanities and Social Sciences (HuSS)
#
# 15
# Programme-linked Courses
# 12.5
# Departmental Courses
# Departmental Core
# 59.5
# Departmental Electives
#
# 6
# Open Category Courses
#
# 12
# Total B.Tech. Credit requirement
# 148
# Non Graded Units
#
# 11
# M.Tech. Part
# Programme Core Courses
#
# 24
# Programme Electives Courses
#
# 18
# Total M.Tech. Requirement
#
# 42
# Total Graded Requirement
# 190
# Institute Core : Basic Sciences
# CML101 Introduction to Chemistry
# 3 1 0 4
# CMP100 Chemistry Laboratory
# 0 0 4 2
# MTL100 Calculus
# 3 1 0 4
# MTL101 Linear Algebra and Differential Equations
# 3 1 0 4
# PYL101 Electromagnetism & Quantum Mechanics
# 3 1 0 4
# PYP100 Physics Laboratory
# 0 0 4 2
# SBL100 Introductory Biology for Engineers
# 3 0 2 4
# Total Credits
#
#
#
# 24
# Institute Core: Engineering Arts and Sciences
# APL100 Engineering Mechanics
# 3 1 0 4
# COL100 Introduction to Computer Science
# 3 0 2 4
# CVL100 Environmental Science
# 2 0 0 2
# ELL101 Introduction to Electrical Engineering
# 3 1 0 4
# ELP101 Introduction to Electrical Engineering (Lab) 0 0 2 1
# MCP100 Introduction to Engineering Visualization
# 0 0 4 2
# MCP101 Product Realization through Manufacturing 0 0 4 2
# Total Credits
#
#
#
# 19
# Programme-Linked Basic / Engineering Arts / Sciences Core
# COL106 Data Structures and Algorithms
# 3 0 4 5
# ELL201 Digital Electronics
# 3 0 3 4.5
# PYL102 Principles of Electronic Materials
# 3 0 0 3
# Total Credits
#
#
#
# 12.5
# Humanities and Social Sciences
# Courses from Humanities, Social Sciences and Management
# offered under this category
#
#
#
# 15
# Departmental Core
# ELL305 Computer Architecture
# 3 0 0 3
# ELP305 Design and System Laboratory
# 0 0 3 1.5
# MTL102 Differential Equations
# 3 0 0 3
# MTL103 Optimization Methods and Applications
# 3 0 0 3
# MTL104 Linear Algebra and Applications
# 3 0 0 3
# MTL105 Algebra
# 3 0 0 3
# MTL106 Probability and Stochastic Processes
# 3 1 0 4
# MTL107 Numerical Methods and Computations
# 3 0 0 3
# MTL122 Real and Complex Analysis
# 3 1 0 4
# MTL180 Discrete Mathematical Structures
# 3 1 0 4
# MTP290 Computing Laboratory
# 0 0 4 2
# MTL342 Analysis and Design of Algorithms
# 3 1 0 4
# MTL783 Theory of Computation
# 3 0 0 3
# MTL390 Statistical Methods
# 3 1 0 4
# MTL411 Functional Analysis
# 3 0 0 3
# MTL445 Computational Methods for
# 3 0 2 4
# Differential Equations
# MTL458 Operating Systems
# 3 0 2 4
# Department of Mathematics
#
# MTL712 Computational Methods for Differential
# 3 0 2 4
#
# Equations
# MTL782 Data Mining
# 3 0 2 4
#
# Total Credits
#
#
# 63.5
# Departmental Electives
# COL334 Computer Networks
# 3 0 2 4
# ELL365 Embedded Systems
# 3 0 0 3
# MTL145 Number Theory
# 3 0 0 3
# MTL146 Combinatorics
# 3 0 0 3
# MTL260 Boundary Value Problems
# 3 0 0 3
# MTL265 Mathematical Programming Techniques
# 3 0 0 3
# MTL270 Measure Integral and Probability
# 3 0 0 3
# MTD350 Mini Project
# 0 0 6 3
# MTL415 Parallel Algorithms
# 3 0 0 3
# MTL736 Analytic Number Theory
# 3 0 0 3
# MTL768 Graph Theory
# 3 0 0 3
# MTL773 Wavelets and Applications
# 3 0 0 3
# MTL780 Parameterized Algorithms for NP-hard
# 3 0 0 3
#
# Problems
# MTL799 Mathematical Analysis in Learning Theory
# 3 0 0 3
# Program Core
# MTL766 Multivariate Statistical Methods
# 3 0 0 3
# MTL781 Finite Elements and Applications
# 3 0 0 3
# MTD851 Major Project Part-I (MT)
# 0 0 12 6
# MTD852  Major Project Part-II (MT)
# 0 0 24 12
# MTD853* Major Project Part-I
# 0 0 8 4
# MTD854* Major Project Part-II
# 0 0 28 14
#
# Total Credits
#
#
#
# 22
# *MTD853 and MTD854 together are alternatives to MTD851 and
# MTD852
# Program Electives
# COL728 Compiler Design
# 3 0 3 4.5
# ELL715 Digital Image Processing
# 3 0 2 4
# ELL786 Multimedia Systems
# 3 0 0 3
# ELL789 Intelligent Systems
# 3 0 0 3
# ELL792 Computer Graphics
# 3 0 0 3
# ELL793 Computer Vision
# 3 0 0 3
# ELL884 Information Retrieval
# 3 0 0 3
# MTL704 Numerical Optimization
# 3 0 0 3
# MTL717 Fuzzy Sets and Applications
# 3 0 0 3
# MTL720 Neurocomputing and Applications
# 3 0 0 3
# MTL725 Stochastic Processes and its Applications
# 3 0 0 3
# MTL728 Category Theory
# 3 0 0 3
# MTL729 Computational Algebra and its Applications 3 0 0 3
# MTL730 Cryptography
# 3 0 0 3
# MTL731 Introduction to Chaotic Dynamical Systems 3 0 0 3
# MTL732 Financial Mathematics
# 3 0 0 3
# MTL733 Stochastic of Finance
# 3 0 0 3
# MTL734 Introductory Actuarial Mathematics
# 3 0 0 3
# MTL735 Advanced Number Theory
# 3 0 0 3
# MTL736 Analytic Number Theory
# 3 0 0 3
# MTL738 Commutative Algebra
# 3 0 0 3
# MTL739 Representation of Finite Groups
# 3 0 0 3
# MTL741 Fractal Geometry
# 3 0 0 3
# MTL742 Operator Theory
# 3 0 0 3
# MTL743 Fourier Analysis
# 3 0 0 3
# MTL744 Mathematical Theory of Coding
# 3 0 0 3
# MTL745 Advanced Matrix Theory
# 3 0 0 3
# MTL747 Mathematical Logic
# 3 0 0 3
# MTL751 Symbolic Dynamics
# 3 0 0 3
# MTL754 Principles of Computer Graphics
# 3 0 0 3
# MTL755 Algebraic Geometry
# 3 0 0 3
# MTL756 Lie Algebras and Lie Groups
# 3 0 0 3
# MTL757 Introduction to Algebraic Topology
# 3 0 0 3
#
# MTL760 Advanced Algorithms
# 3 0 0 3
# MTL761 Basic Ergodic Theory
# 3 0 0 3
# MTL762 Probability Theory
# 3 0 0 3
# MTL763 Introduction to Game Theory
# 3 0 0 3
# MTL780 Parameterized Algorithms for NP-hard
# 3 0 0 3
# Problems
# MTL785 Natural Language Processing
# 3 0 0 3
# MTL792 Modern Methods in Partial
# 3 0 0 3
# Differential equations
# MTL793 Numerical Methods for Hyperbolic PDEs
# 3 0 0 3
# MTL794 Advanced Probability Theory
# 3 0 0 3
# MTL795 Numerical Method for Partial
# 3 1 0 4
# Differential Equations
# MTV791 Special Module in Dynamical System
# 1 0 0 1
#
# MTL811 Mathematical Foundation of Artificial
# 3 0 0 3
#
# Intelligence
# MTL843 Mathematical Modeling of Credit Risk
# 3 0 0 3
# MTL851 Applied Numerical Analysis
# 3 0 0 3
# MTL854 Interpolation and Approximation
# 3 0 0 3
# MTL855 Multiple Decision Procedures in Ranking
# 3 0 0 3
#
# and Selection
# MTL860 Linear Algebra
# 3 0 0 3
# MTL863 Algebraic Number Theory
# 3 0 0 3
# MTV874 Analysis
# 3 0 0 3
# MTL882 Applied Analysis
# 3 0 0 3
# MTL883 Physical Fluid Mechanics
# 3 0 0 3
# MTL888 Boundary Elements Methods with
# 3 0 0 3
#
# Computer Implementation

# %% [markdown]
# ## TODO
#
# - Extract core course codes for each program
# - Construct database of core courses.

# %%
def parse_course(course):

# %%
print(course_body)

# %%
def parse_course(course):

    template = {
            "code": "CS1",
            "name": "B.Tech in Computer Science and Engineeering",
            "credits" : {
                "BS": 24,
                "EAS": 19,
                "HuSS": 15,
                "PL": 0,
                "DC": 0,
                "DE": 0,
                "OC": 0,
                "MTech" : {
                    "PC": 0,
                    "PE": 0,
                }
            },
            "courses": {
                "PL": [],
                "DC": [],
                "DE": [],
                "MTech": {
                    "PC": [],
                    "PE": []
                }
            },
            "recommended" : { i+1: [] for i in range(8) }
        }

    template['code'] = course['header'][0].split(' ')[-1]
    template['name'] = course['header'][1]
    if template['code'] == 'DD1':
        return template

    i = 0
    cbody = course['body']

    line_map = {
        'Programme-linked Courses': 'PL',
        'Departmental Core': 'DC',
        'Departmental Electives': 'DE',
        'Open Category Courses': 'OC'
    }
    
    while i < len(cbody) :
        for (l, c) in line_map.items():
            if cbody[i] == l and template['credits'][c] == 0:
                i += 1
                while i < len(cbody) and cbody[i] == '':
                    i += 1
                template['credits'][c] = float(cbody[i])

        i += 1

    assert template['credits']['PL'] > 0, f"Could not parse PL for code {template['code']}"
    assert template['credits']['DC'] > 0, f"Could not parse DC for code {template['code']}"
    assert template['credits']['DE'] > 0, f"Could not parse DE for code {template['code']}"
    assert template['credits']['OC'] > 0, f"Could not parse OC for code {template['code']}"

    course_map = {
        'Programme-Linked Basic / Engineering Arts / Sciences Core' : 'PL',
        'Departmental Core': 'DC',
        'Departmental Electives': 'DE'
    }

    re_digit = r'\d'

    i = 28
    while i < len(cbody):
        for (l, c) in course_map.items():
            if cbody[i] == l and not template['courses'][c]:
                # print(f"Parsing {c} for {template['code']}")
                # parse courses 
                while i < len(cbody)-1:
                    i += 1
                    if cbody[i] == '':
                        continue
                    if cbody[i] == "Total Credits":
                        break
                    toks = cbody[i].split(' ')
                    if re.match(COURSE_PATTERN, toks[0]):
                        # print(f"Got course {toks[0]}")
                        template['courses'][c].append(toks[0])
        i += 1

    assert template['courses']['PL'] != [], f"Could not parse PL courses for code {template['code']}"
    assert template['courses']['DC'] != [], f"Could not parse DC courses for code {template['code']}"
    assert template['courses']['DE'] != [], f"Could not parse DE courses for code {template['code']}"
    
    return template

# %%
parsed_courses = {}

for course in all_courses:
    p = parse_course(course)
    parsed_courses[p['code']] = p

# %%
parsed_courses['EE1']
# Out:
# {'code': 'EE1',
#  'name': 'Bachelor of Technology in Electrical Engineering',
#  'credits': {'BS': 24,
#   'EAS': 19,
#   'HuSS': 15,
#   'PL': 15.0,
#   'DC': 60.0,
#   'DE': 10.0,
#   'OC': 10.0,
#   'MTech': {'PC': 0, 'PE': 0}},
#  'courses': {'PL': ['COL106', 'MTL106', 'MCL142', 'PYL102'],
#   'DC': ['ELL201',
#    'ELL202',
#    'ELL203',
#    'ELP203',
#    'ELL205',
#    'ELL211',
#    'ELL212',
#    'ELP212',
#    'ELL225',
#    'ELP225',
#    'ELL302',
#    'ELP302',
#    'ELL303',
#    'ELP303',
#    'ELL304',
#    'ELL305',
#    'ELP305',
#    'ELL311',
#    'ELP311',
#    'ELD411'],
#   'DE': ['ELL301',
#    'ELL312',
#    'ELL313',
#    'ELL315',
#    'ELL316',
#    'ELL318',
#    'ELL319',
#    'ELL332',
#    'ELL333',
#    'ELL365',
#    'ELL400',
#    'ELL401',
#    'ELL402',
#    'ELL405',
#    'ELL406',
#    'ELL407',
#    'ELL409',
#    'ELL410',
#    'ELL411',
#    'ELL703',
#    'ELL710',
#    'ELL715',
#    'ELL716',
#    'ELL725',
#    'ELL730',
#    'ELL738',
#    'ELL740',
#    'ELL758',
#    'ELL765',
#    'ELS310'],
#   'MTech': {'PC': [], 'PE': []}},
#  'recommended': {1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: [], 8: []}}
