# %%
from openpyxl import Workbook
from openpyxl import load_workbook
from tqdm.notebook import tqdm
from os import listdir
import pandas as pd
import tabula
from faker import Factory
from collections import defaultdict

# %%
# %pip install faker
# Out:
# Collecting faker
#   Using cached Faker-19.3.1-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\arush bansal\anaconda3\lib\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\arush bansal\anaconda3\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-19.3.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Cleaning up Courses Offered
#
# IITD Eacads puts the courses offered up as a very very messy CSV file (they probably export it from the excel themselves) and the excel has a lot of blank merged columns, so it's easier to download the excel file and strip the useless stuff out of it, then export to CSV.

# %%
COURSES_OFFERED_RAW_PATH = "./data/courses_offered_raw"
COURSES_OFFERED_CLEAN_PATH = "data/courses_offered"
COURSES_OFFERED_ANON = "data/courses_offered_anon"

# %%
datasheets = listdir(COURSES_OFFERED_RAW_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\ARUSHB~1\AppData\Local\Temp/ipykernel_13984/623268288.py in <module>
# ----> 1 datasheets = listdir(COURSES_OFFERED_RAW_PATH)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './data/courses_offered_raw'

# %%
def clean_dataframe(df):
    df.columns = df.iloc[0]
    df = df.drop([0])
    df = df.astype({'S.No': 'int32', "Vacancy": "int32", "Current Strength": "int32"})
    df = df.set_index(["S.No"])
    cname_spl = df['Course Name'].str.rsplit('-',1,expand=True)
    (ccode, cname) = (cname_spl[1], cname_spl[0])
    df['Course Name'] = cname
    df['Course Code'] = ccode.str.strip().str.replace(" ","")
    df['Instructor'] = df['Instructor'].str.strip()
    return df

# %%
# takes around 10.5 seconds per file, so quite slow
course_dfs = {}
for name in tqdm(datasheets):
    print(name)
    name_no_ext = name.split(".")[0]
    wb = load_workbook(f"{COURSES_OFFERED_RAW_PATH}/{name}")
    ws = wb[wb.sheetnames[0]]
    cols_to_delete = [3,5,7,10,12,13,16,18,21]
    i = 0
    for col in cols_to_delete:
        ws.delete_cols(col-i)
        i += 1
    ws.delete_rows(1,4)
    df = pd.DataFrame(ws.values)
    df = clean_dataframe(df)
    course_dfs[name_no_ext] = df
    #df.to_csv(f"{COURSES_OFFERED_CLEAN_PATH}/{name_no_ext}.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ARUSHB~1\AppData\Local\Temp/ipykernel_13984/2899516416.py in <module>
#       1 # takes around 10.5 seconds per file, so quite slow
#       2 course_dfs = {}
# ----> 3 for name in tqdm(datasheets):
#       4     print(name)
#       5     name_no_ext = name.split(".")[0]
#
# NameError: name 'datasheets' is not defined

# %% [markdown]
# ## Anonymizing the Data
#
# The Eacademics data is not anonymized wrt professor names, so it's best to go ahead and anonymize before publishing.

# %%
faker = Factory.create('en_IN')
dictnames = defaultdict(faker.simple_profile)

mapping_dict = {}

def change(row):
    email_split = row['Instructor Email'].split("@")
    ename, eaddress = email_split[0], email_split[1]
    email = f"{dictnames[ename]['username']}@{eaddress}"
    name = dictnames[ename]['name']
    row['Instructor Email'] = email
    row['Instructor'] = name.upper()
    mapping_dict[ename] = (name.upper(),email)
    return row

for name in tqdm(course_dfs):
    df = course_dfs[name]
    df_new = df.apply(change, axis=1)
    df_new.to_csv(f"{COURSES_OFFERED_ANON}/{name}.csv")

mapping = []
for key,value in mapping_dict.items():
    mapping.append({"kerberos": key, "name": value[0], "email": value[1]})
    
df_mapping = pd.DataFrame(mapping)
df_mapping.to_csv(f"data/anon_mapping.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ARUSHB~1\AppData\Local\Temp/ipykernel_13984/2946932793.py in <module>
#      14     return row
#      15
# ---> 16 for name in tqdm(course_dfs):
#      17     df = course_dfs[name]
#      18     df_new = df.apply(change, axis=1)
#
# NameError: name 'course_dfs' is not defined

# %% [markdown]
# ## Course Data
#
# The course structures have to be taken from the Courses of Study; There's no _clean_ way that I could find of doing this, so it's partly manual labour and partly using some utility scripts to generate the credit structure/timetable/DE/PL data.

# %%
COS = "Courses-of-Study_2020-2021.pdf"

PROGRAM_4Y_PAGE = {
    "AM1": 44,
    "BB1": 46,
    "CH1": 48,
    "CE1": 53,
    "CS1": 55,
    "EE1": 60,
    "EE3": 62,
    "MS1": 64,
    "ME1": 66,
    "ME2": 68,
    "MT1": 70,
    "PH1": 75,
    "TT1": 77
}
PROGRAM_5Y_PAGE = {
    "CH7": 50,
    "CS5": 57,
    "MT6": 72
}

COLUMNS_LHS = [80, 257, 265, 276, 287]
AREA_LHS = [220, 40, 800, 297]

COLUMNS_RHS = [343, 511, 520, 530, 540]
AREA_RHS = [94, 309, 800, 560]

COLUMNS_CRED_STRUCT = [242]
AREA_CRED_STRUCT_4Y = [106, 40, 220, 295]
AREA_CRED_STRUCT_5Y = [106, 40, 290, 295]

CPLAN_IDX_4Y = [0, 3, 7, 10, 13, 16, 19, 22]
CPLAN_IDX_5Y = [0, 3, 7, 10, 13, 16, 19, 22, 25, 28]
CPLAN_IDX_5Y_SUMMER = [0, 3, 7, 10, 13, 16, 19, 22, 26, 29]

COMMON_COURSES = """
    <eas>
      <course>APL100</course>
      <course>CVL100</course>
      <course>COL100</course>
      <course>ELL101</course>
      <course>MCP100</course>
      <course>MCP101</course>
    </eas>
    <bs>
      <course>CML101</course>
      <course>CMP100</course>
      <course>MTL100</course>
      <course>MTL101</course>
      <course>PYL101</course>
      <course>PYP100</course>
      <course>SBL100</course>
    </bs>
"""

FILE_LOC = "data/course_plans_temp"

# %%
for dep in tqdm(PROGRAM_4Y_PAGE):
    strlist = []
    pgno = PROGRAM_4Y_PAGE[dep]
    cred_struct = tabula.read_pdf(COS, area=AREA_CRED_STRUCT_4Y, columns=[242], pages=[pgno])[0]
    cs = {'bs': 24, 'eas': 19, 'huss': 15}
    cs['pl'] = cred_struct.iloc[4][1]
    cs['dc'] = cred_struct.iloc[6][1]
    cs['de'] = cred_struct.iloc[7][1]
    cs['oe'] = cred_struct.iloc[8][1]
    strlist.append(f'<program name="{dep}" type="4y">\n  <credits>\n')
    for key in cs:
        strlist.append(f"    <{key}>{cs[key]:g}</{key}>\n")
    strlist.append('  </credits>\n  <courses>')
    strlist.append(COMMON_COURSES)
    strlist.append('  </courses>\n  <recommended>\n')
    
    plan = tabula.read_pdf(COS, pages=[pgno+1])[0]
    for (i,sem) in zip(range(8),CPLAN_IDX_4Y):
        strlist.append(f'    <sem num="{i+1}">\n')
        for c in plan.iloc[sem][1:10]:
            if not pd.isna(c):
                course = c.replace(" ","")
                strlist.append(f'      <course>{course}</course>\n')
        strlist.append(f'    </sem>\n')
    strlist.append('  </recommended>\n</program>')
        
    with open(f"{FILE_LOC}/{dep}.xml", "w") as f:
        f.write("".join(strlist))
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
for dep in tqdm(PROGRAM_5Y_PAGE):
    strlist = []
    pgno = PROGRAM_5Y_PAGE[dep]
    plan = tabula.read_pdf(COS, pages=[pgno+2])[0]
    plist = CPLAN_IDX_5Y if dep == "MT6" else CPLAN_IDX_5Y_SUMMER
    for (i,sem) in zip(range(10),plist):
        strlist.append(f'    <sem num="{i+1}">\n')
        for c in plan.iloc[sem][1:10]:
            if not pd.isna(c):
                course = c.replace(" ","")
                strlist.append(f'      <course>{course}</course>\n')
        strlist.append(f'    </sem>\n')
    
    print("".join(strlist))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
#     <sem num="1">
#       <course>ELL101</course>
#       <course>MCP100</course>
#       <course>PYL101</course>
#       <course>MTL100</course>
#       <course>PYP100</course>
#       <course>MCP101</course>
#       <course>NIN100</course>
#       <course>NEN100</course>
#       <course>NLN100</course>
#     </sem>
#     <sem num="2">
#       <course>APL100</course>
#       <course>COL100</course>
#       <course>CML101</course>
#       <course>MTL101</course>
#       <course>CMP100</course>
#       <course>NEN101</course>
#       <course>NLN101</course>
#     </sem>
#     <sem num="3">
#       <course>CLL110</course>
#       <course>CLL111</course>
#       <course>CLL113</course>
#       <course>CML103</course>
#       <course>HUL2XX</course>
#       <course>CLN101</course>
#     </sem>
#     <sem num="4">
#       <course>CLL121</course>
#       <course>CLL122</course>
#       <course>CLL231</course>
#       <course>CLL251</course>
#       <course>SBL100</course>
#       <course>APL102</course>
#     </sem>
#     <sem num="5">
#       <course>CLL252</course>
#       <course>CLL222</course>
#       <course>CLL331</course>
#       <course>CLL141</course>
#       <course>CLL261</course>
#       <course>CVL100</course>
#       <course>CLP301</course>
#     </sem>
#     <sem num="6">
#       <course>CLL352</course>
#       <course>DE1</course>
#       <course>CLL271</course>
#       <course>CLL371</course>
#       <course>CLL361</course>
#       <course>HUL2XX</course>
#       <course>CLP302</course>
#     </sem>
#     <sem num="7">
#       <course>DE2</course>
#       <course>PE1</course>
#       <course>PE2</course>
#       <course>CLP303</course>
#       <course>CLL703</course>
#       <course>HUL2XX</course>
#       <course>OC1</course>
#     </sem>
#     <sem num="8">
#       <course>PE3</course>
#       <course>DE3</course>
#       <course>CLD880</course>
#       <course>HUL3XX</course>
#       <course>CLL731</course>
#       <course>CLL733</course>
#     </sem>
#     <sem num="9">
#       <course>CLD881</course>
#       <course>PE4</course>
#       <course>OE1</course>
#     </sem>
#     <sem num="10">
#       <course>CLD882</course>
#     </sem>
#
#     <sem num="1">
#       <course>ELL101</course>
#       <course>MCP100</course>
#       <course>PYL101</course>
#       <course>MTL100</course>
#       <course>PYP100</course>
#       <course>MCP101</course>
#       <course>NIN100</course>
#       <course>NEN100</course>
#       <course>NLN100</course>
#     </sem>
#     <sem num="2">
#       <course>APL100</course>
#       <course>COL100</course>
#       <course>CML101</course>
#       <course>MTL101</course>
#       <course>CMP100</course>
#       <course>NEN101</course>
#       <course>NLN101</course>
#     </sem>
#     <sem num="3">
#       <course>COL202</course>
#       <course>COL215</course>
#       <course>COL106</course>
#       <course>PYLXXX</course>
#       <course>MTL106</course>
#       <course>C0N101</course>
#     </sem>
#     <sem num="4">
#       <course>COL226</course>
#       <course>COL216</course>
#       <course>ELL205</course>
#       <course>CVL100</course>
#       <course>HUL2XX</course>
#       <course>COP290</course>
#     </sem>
#     <sem num="5">
#       <course>COL333/DE1</course>
#       <course>COL334</course>
#       <course>COL351</course>
#       <course>SBL100</course>
#       <course>HUL2XX</course>
#       <course>Cou</course>
#       <course>se-4</course>
#     </sem>
#     <sem num="6">
#       <course>COL362/DE1</course>
#       <course>COL331</course>
#       <course>COL352</course>
#       <course>MTLXXX</course>
#       <course>HUL2XX</course>
#       <course>COL380</course>
#     </sem>
#     <sem num="7">
#       <course>DE2(3)</course>
#       <course>DE3(4)</course>
#       <course>COL703</course>
#       <course>OC1(3)</course>
#       <course>PE1(3)</course>
#     </sem>
#     <sem num="8">
#       <course>COD891</course>
#       <course>COL726</course>
#       <course>HUL3XX</course>
#       <course>PE2(3)</course>
#       <course>PE3(3)</course>
#       <course>OC(2)</course>
#     </sem>
#     <sem num="9">
#       <course>PE4(3)</course>
#       <course>PE5(3)</course>
#       <course>COD892</course>
#       <course>OC(3)</course>
#     </sem>
#     <sem num="10">
#       <course>COD893</course>
#     </sem>
#
#     <sem num="1">
#       <course>ELL101</course>
#       <course>MCP100</course>
#       <course>PYL101</course>
#       <course>MTL100</course>
#       <course>PYP100</course>
#       <course>MCP101</course>
#       <course>NIN100</course>
#       <course>NEN100</course>
#       <course>NLN100</course>
#     </sem>
#     <sem num="2">
#       <course>APL100</course>
#       <course>COL100</course>
#       <course>CML101</course>
#       <course>MTL101</course>
#       <course>CMP100</course>
#       <course>NEN101</course>
#       <course>NLN101</course>
#     </sem>
#     <sem num="3">
#       <course>COL106</course>
#       <course>MTL180</course>
#       <course>PYL102</course>
#       <course>CVL100</course>
#       <course>MTL104</course>
#       <course>HUL2XX</course>
#       <course>MTN101</course>
#     </sem>
#     <sem num="4">
#       <course>MTL122</course>
#       <course>ELL201</course>
#       <course>MTL103</course>
#       <course>SBL100</course>
#       <course>MTP290</course>
#       <course>HUL2XX</course>
#     </sem>
#     <sem num="5">
#       <course>MTL106</course>
#       <course>ELL305</course>
#       <course>MTL105</course>
#       <course>MTL107</course>
#       <course>MTL342</course>
#       <course>HUL2XX</course>
#     </sem>
#     <sem num="6">
#       <course>MTL102</course>
#       <course>MTL782</course>
#       <course>MTL390</course>
#       <course>MTL411</course>
#       <course>DE1</course>
#       <course>ELP305</course>
#     </sem>
#     <sem num="7">
#       <course>MTL712</course>
#       <course>MTL783</course>
#       <course>DE2</course>
#       <course>MTL458</course>
#       <course>OC1</course>
#       <course>HUL3XX</course>
#     </sem>
#     <sem num="8">
#       <course>OC2</course>
#       <course>OE1</course>
#       <course>PE1</course>
#       <course>PE2</course>
#       <course>PE3</course>
#       <course>PE4</course>
#     </sem>
#     <sem num="9">
#       <course>MTD851</course>
#       <course>MTL781</course>
#       <course>MTL766</course>
#       <course>PE5</course>
#       <course>PE6</course>
#       <course>OE2</course>
#     </sem>
#     <sem num="10">
#       <course>MTD852</course>
#     </sem>

# %% [markdown]
# ### Scratch

# %%
df = tabula.read_pdf(COS, pages=[52])[0]
df
# Out:
#                                            Unnamed: 0  \
# 0                                                   I
# 1                                                 NaN
# 2                                                 NaN
# 3                                                  II
# 4                                                 NaN
# 5                                                 NaN
# 6   Note: Courses 1-6 above are attended in the gi...
# 7                                                 III
# 8                                                 NaN
# 9                                                 NaN
# 10                                                 IV
# 11                                                NaN
# 12                                                NaN
# 13                                                  V
# 14                                                NaN
# 15                                                NaN
# 16                                                 VI
# 17                                                NaN
# 18                                                NaN
# 19                                                VII
# 20                                                NaN
# 21                                                NaN
# 22                                               VIII
# 23                                                NaN
# 24                                                NaN
# 25                                             Summer
# 26                                                 IX
# 27                                                NaN
# 28                                                NaN
# 29                                                  X
# 30                                   Major Project II
# 31                                             002412
#
#                                  Unnamed: 1  \
# 0                                    ELL101
# 1   Introduction to Electrical\rEngineering
# 2                                      3125
# 3                                    APL100
# 4                     Engineering Mechanics
# 5                                      3104
# 6                                       NaN
# 7                                    CLL110
# 8                       Transport Phenomena
# 9                                      3104
# 10                                   CLL121
# 11     Chemical Engineering\rThermodynamics
# 12                                     3104
# 13                                   CLL252
# 14                          Mass Transfer I
# 15                                     3003
# 16                                   CLL352
# 17                         Mass Transfer II
# 18                                     3104
# 19                                     DE 2
# 20                                      NaN
# 21                                     3003
# 22                                     PE 3
# 23                                      NaN
# 24                                     3003
# 25                                      NaN
# 26                                   CLD881
# 27                          Major Project I
# 28                                    00168
# 29                                   CLD882
# 30                                      NaN
# 31                                      NaN
#
#                                     Unnamed: 2  \
# 0                                       MCP100
# 1   Introduction to Engineering\rVisualization
# 2                                         0042
# 3                                       COL100
# 4            Introduction to Computer\rScience
# 5                                         3024
# 6                                          NaN
# 7                                       CLL111
# 8                Material and Energy\rBalances
# 9                                         2204
# 10                                      CLL122
# 11            Chemical Reaction\rEngineering I
# 12                                        3104
# 13                                      CLL222
# 14           Chemical Reaction\rEngineering II
# 15                                        3003
# 16                                        DE 1
# 17                                         NaN
# 18                                        3003
# 19                                        PE 1
# 20                                         NaN
# 21                                        3003
# 22                                        DE 3
# 23                                         NaN
# 24                                        3003
# 25                                         NaN
# 26                                        PE 4
# 27                                         NaN
# 28                                        3003
# 29                                         NaN
# 30                                         NaN
# 31                                         NaN
#
#                                       Unnamed: 3  \
# 0                                         PYL101
# 1   Electromagnetic Waves\rand Quantum Mechanics
# 2                                           3104
# 3                                         CML101
# 4                      Introduction to Chemistry
# 5                                           3104
# 6                                            NaN
# 7                                         CLL113
# 8     Numerical Methods in\rChemical Engineering
# 9                                           3024
# 10                                        CLL231
# 11       Fluid Mechanics for\rChemical Engineers
# 12                                          3104
# 13                                        CLL331
# 14                      Fluid-Particle Mechanics
# 15                                          3104
# 16                                        CLL271
# 17     Introduction to Industrial\rBiotechnology
# 18                                          3003
# 19                                          PE 2
# 20                                           NaN
# 21                                          3003
# 22                                        CLD880
# 23                                 Minor Project
# 24                                          0084
# 25                                           NaN
# 26                                          OE 1
# 27                                           NaN
# 28                                          3003
# 29                                           NaN
# 30                                           NaN
# 31                                           NaN
#
#                                            Unnamed: 4  \
# 0                                              MTL100
# 1                                            Calculus
# 2                                                3104
# 3                                              MTL101
# 4          Linear Algebra and Differential\rEquations
# 5                                                3104
# 6                                                 NaN
# 7                                              CML103
# 8         Applied Chemistry: Chemistry\rat Interfaces
# 9                                                3003
# 10                                             CLL251
# 11              Heat Transfer for Chemical\rEngineers
# 12                                               3104
# 13                                             CLL141
# 14  Introduction to Materials for\rChemical Engineers
# 15                                               3003
# 16                                             CLL371
# 17         Chemical Process Technology\rand Economics
# 18                                               3104
# 19                                             CLP303
# 20               Chemical Engineering\rLaboratory III
# 21                                             0031.5
# 22                                             HUL3XX
# 23                                                NaN
# 24                                               3003
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                              Unnamed: 5  \
# 0                                PYP100
# 1                    Physics Laboratory
# 2                                  0042
# 3                                CMP100
# 4                  Chemistry Laboratory
# 5                                  0042
# 6                                   NaN
# 7                                HUL2XX
# 8                                   NaN
# 9                                  3104
# 10                               SBL100
# 11  Introductory Biology for\rEngineers
# 12                                 3024
# 13                               CLL261
# 14        Process Dynamics and\rControl
# 15                                 3104
# 16                               CLL361
# 17      Instrumentation and\rAutomation
# 18                               1032.5
# 19                               CLL703
# 20                  Process Engineering
# 21                                 3003
# 22                               CLL731
# 23                      Adv Trans Pheno
# 24                                 3003
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
#
#                                                Semest  \
# 0                                              MCP101
# 1          Product Realization through\rManufacturing
# 2                                                0042
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                             APL102
# 11  Introduction to Materials\rScience and Enginee...
# 12                                               3024
# 13                                             CVL100
# 14                              Environmental Science
# 15                                               2002
# 16                                             HUL2XX
# 17                                                NaN
# 18                                               3104
# 19                                             HUL2XX
# 20                                             Course
# 21                                               3104
# 22                                             CLL733
# 23                                   Ind Multiph Reac
# 24                                               3003
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                                     r  \
# 0                                              NIN100
# 1           Introduction to Engineering\r(Non-graded)
# 2                                                0021
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              CLN101
# 8   Introduction to Chemical\rEngineering (Non-gra...
# 9                                                0021
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                             CLP301
# 14                 Chemical Engineering\rLaboratory I
# 15                                             0031.5
# 16                                             CLP302
# 17                Chemical Engineering\rLaboratory II
# 18                                             0031.5
# 19                                               OC 1
# 20                                                  5
# 21                                               3003
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                            Unnamed: 6  \
# 0                                              NEN100
# 1   Professional Ethics and\r\rSocial Responsibili...
# 2                                              0010.5
# 3                                              NEN101
# 4   Professional Ethics and\rSocial Responsibility...
# 5                                              0010.5
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
#
#                                       Unnamed: 7     L    T     P  Unnamed: 8  \
# 0                                         NLN100   9.0  3.0  14.0        19.0
# 1   Language and\rWriting Skills-1\r(Non-Graded)   NaN  NaN   NaN         NaN
# 2                                           0021   NaN  NaN   NaN         NaN
# 3                                         NLN101  12.0  3.0   6.0        18.0
# 4   Language and\rWriting Skills-2\r(Non-Graded)   NaN  NaN   NaN         NaN
# 5                                           0021   NaN  NaN   NaN         NaN
# 6                                            NaN   NaN  NaN   NaN         NaN
# 7                                            NaN  14.0  4.0   2.0        19.0
# 8                                            NaN   NaN  NaN   NaN         NaN
# 9                                            NaN   NaN  NaN   NaN         NaN
# 10                                           NaN  18.0  4.0   4.0        24.0
# 11                                           NaN   NaN  NaN   NaN         NaN
# 12                                           NaN   NaN  NaN   NaN         NaN
# 13                                           NaN  17.0  2.0   3.0        20.5
# 14                                           NaN   NaN  NaN   NaN         NaN
# 15                                           NaN   NaN  NaN   NaN         NaN
# 16                                           NaN  16.0  3.0   6.0        22.0
# 17                                           NaN   NaN  NaN   NaN         NaN
# 18                                           NaN   NaN  NaN   NaN         NaN
# 19                                           NaN  18.0  1.0   3.0        20.5
# 20                                           NaN   NaN  NaN   NaN         NaN
# 21                                           NaN   NaN  NaN   NaN         NaN
# 22                                           NaN  15.0  0.0   8.0        19.0
# 23                                           NaN   NaN  NaN   NaN         NaN
# 24                                           NaN   NaN  NaN   NaN         NaN
# 25                                           NaN   NaN  NaN   NaN         NaN
# 26                                           NaN   6.0  0.0  16.0        14.0
# 27                                           NaN   NaN  NaN   NaN         NaN
# 28                                           NaN   NaN  NaN   NaN         NaN
# 29                                           NaN   0.0  0.0  24.0        12.0
# 30                                           NaN   NaN  NaN   NaN         NaN
# 31                                           NaN   NaN  NaN   NaN         NaN
#
#     Unnamed: 9  Unnamed: 10
# 0          2.5         31.0
# 1          NaN          NaN
# 2          NaN          NaN
# 3          1.5         24.0
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          1.0         22.0
# 8          NaN          NaN
# 9          NaN          NaN
# 10         0.0         26.0
# 11         NaN          NaN
# 12         NaN          NaN
# 13         0.0         22.0
# 14         NaN          NaN
# 15         NaN          NaN
# 16         0.0         25.0
# 17         NaN          NaN
# 18         NaN          NaN
# 19         0.0         22.0
# 20         NaN          NaN
# 21         NaN          NaN
# 22         0.0         23.0
# 23         NaN          NaN
# 24         NaN          NaN
# 25         NaN          NaN
# 26         0.0         22.0
# 27         NaN          NaN
# 28         NaN          NaN
# 29         0.0         24.0
# 30         NaN          NaN
# 31         NaN          NaN

# %%
cred_struct
# Out:
#                          Course Category  Credits
# 0                 Institute Core Courses      NaN
# 1                    Basic Sciences (BS)     24.0
# 2     Engineering Arts and Science (EAS)     19.0
# 3  Humanities and Social Sciences (HuSS)     15.0
# 4               Programme-linked Courses     15.0
# 5                   Departmental Courses      NaN
# 6                      Departmental Core     60.0
# 7                 Departmental Electives     10.0
# 8                  Open Category Courses     10.0
# 9        Total Graded Credit requirement    153.0

# %%
#print(df.dtypes)
for c in df.iloc[22][1:10]:
    if not pd.isna(c):
        print(c)
# Out:
# DE 3
# OC2
# OC3
# HUL3XX

# %%
from mimesis import Generic

fake = Generic()
fake_name = fake.person.full_name()
fake_address = fake.address.address()
fake_email = fake.person.email()
fake_phone_number = fake.person.telephone()
print(f'''{fake}
{fake_name}
{fake_email}
{fake_phone_number}''')
# Out:
# Generic <Locale.EN>
# Arnold Harvey
# renewal1923@live.com
# +1-228-049-0532
