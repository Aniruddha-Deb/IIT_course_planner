# %%
from bs4 import BeautifulSoup
import pandas as pd
import networkx as nx
import re
import os
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import write_dot
from tqdm.notebook import tqdm

# %%
RCDATA = "data/cos_course_data_raw.xml"

# %%
with open(RCDATA, 'r', encoding='utf-8') as cdata:
    s = "".join(cdata.readlines())
    tree = BeautifulSoup(s)

# %%
rows = []
for dep in tree.findAll("courses"):
    for course in dep.findAll("course"):
        rows.append({
            "code": getattr(course.find("code"), "string", None),
            "name": getattr(course.find("name"), "string", None),
            "credits": getattr(course.find("credits"), "string", None),
            "credit-structure": getattr(course.find("credit-structure"), "string", None),
            "pre-requisites": getattr(course.find("pre-requisites"), "string", None),
            "overlap": getattr(course.find("overlap"), "string", None),
            "department": dep.get("department"),
            "description": getattr(course.find("description"), "string", None)
        })
        
df = pd.DataFrame(rows)

# %%
df
# Out:
#         code                                               name credits  \
# 0     APL100                              Engineering Mechanics       4
# 1     APL101    Applied Mathematics in Engineering Applications       3
# 2     APL102  Introduction to Materials Science and Engineering       4
# 3     APL103                               Experimental Methods       4
# 4     APL104                                    Solid Mechanics       4
# ...      ...                                                ...     ...
# 2387  JOL794                                 Selected Topics-II       3
# 2388  JOS795                                  Independent Study       3
# 2389  JOV796                       Selected Topics in Photonics       1
# 2390  JOD801                               Major Project Part-I       6
# 2391  JOD802                              Major Project Part-II      12
#
#      credit-structure pre-requisites         overlap  \
# 0               3-1-0           None            None
# 1               3-0-0           None            None
# 2               3-0-2           None            None
# 3               3-0-2           None            None
# 4               3-1-0         APL100  APL105, APL108
# ...               ...            ...             ...
# 2387            3-0-0           None            None
# 2388            0-3-0           None            None
# 2389            1-0-0           None            None
# 2390           0-0-12           None            None
# 2391           0-0-24           None            None
#
#                                        department  \
# 0                 Department of Applied Mechanics
# 1                 Department of Applied Mechanics
# 2                 Department of Applied Mechanics
# 3                 Department of Applied Mechanics
# 4                 Department of Applied Mechanics
# ...                                           ...
# 2387  Department of Textile and Fibre Engineering
# 2388  Department of Textile and Fibre Engineering
# 2389  Department of Textile and Fibre Engineering
# 2390  Department of Textile and Fibre Engineering
# 2391  Department of Textile and Fibre Engineering
#
#                                             description
# 0     Kinematics, Statics, Equations of Motion, Rigi...
# 1     ordinary Differential Equation: Second order o...
# 2     Structure of Solids: atomic and inter-atomic b...
# 3     Experimental Analysis: Types of measurements a...
# 4     Introduction, State of stress at a point, equa...
# ...                                                 ...
# 2387                                               None
# 2388                                               None
# 2389                                               None
# 2390                                               None
# 2391                                             0-0-24
#
# [2392 rows x 8 columns]

# %% [markdown]
# ## Pre-Processing
# Add year + semwise data

# %%
YEARS = ["2122", "2021", "1920"]
COURSES_OFFERED_PATH = "data/courses_offered_anon"
year = YEARS[2]
i = 2
for year in YEARS:
    for i in [1,2]:
        sem_yr_data = pd.read_csv(f"{COURSES_OFFERED_PATH}/{i}_{year}.csv")
        sem_yr_data = sem_yr_data.rename(columns={'Course Code': 'code'})
        # drop all courses with the slot as SU1 or X
        sem_yr_data = sem_yr_data.loc[(sem_yr_data['Slot Name'] != 'X') & (~sem_yr_data['Slot Name'].str.startswith('SU'))]
        df = df.merge(sem_yr_data[['code','Slot Name', 'Vacancy', 'Current Strength']],on='code',how='left')
        df = df.rename(columns={'Slot Name': f"{i}_{year}_slot", 'Vacancy': f"{i}_{year}_vacancy", 'Current Strength': f"{i}_{year}_strength"})

df
# Out:
#         code                                               name credits  \
# 0     APL100                              Engineering Mechanics       4
# 1     APL101    Applied Mathematics in Engineering Applications       3
# 2     APL102  Introduction to Materials Science and Engineering       4
# 3     APL103                               Experimental Methods       4
# 4     APL104                                    Solid Mechanics       4
# ...      ...                                                ...     ...
# 2747  JOL794                                 Selected Topics-II       3
# 2748  JOS795                                  Independent Study       3
# 2749  JOV796                       Selected Topics in Photonics       1
# 2750  JOD801                               Major Project Part-I       6
# 2751  JOD802                              Major Project Part-II      12
#
#      credit-structure pre-requisites         overlap  \
# 0               3-1-0           None            None
# 1               3-0-0           None            None
# 2               3-0-2           None            None
# 3               3-0-2           None            None
# 4               3-1-0         APL100  APL105, APL108
# ...               ...            ...             ...
# 2747            3-0-0           None            None
# 2748            0-3-0           None            None
# 2749            1-0-0           None            None
# 2750           0-0-12           None            None
# 2751           0-0-24           None            None
#
#                                        department  \
# 0                 Department of Applied Mechanics
# 1                 Department of Applied Mechanics
# 2                 Department of Applied Mechanics
# 3                 Department of Applied Mechanics
# 4                 Department of Applied Mechanics
# ...                                           ...
# 2747  Department of Textile and Fibre Engineering
# 2748  Department of Textile and Fibre Engineering
# 2749  Department of Textile and Fibre Engineering
# 2750  Department of Textile and Fibre Engineering
# 2751  Department of Textile and Fibre Engineering
#
#                                             description 1_2122_slot  \
# 0     Kinematics, Statics, Equations of Motion, Rigi...           A
# 1     ordinary Differential Equation: Second order o...           B
# 2     Structure of Solids: atomic and inter-atomic b...         NaN
# 3     Experimental Analysis: Types of measurements a...           F
# 4     Introduction, State of stress at a point, equa...           D
# ...                                                 ...         ...
# 2747                                               None         NaN
# 2748                                               None         NaN
# 2749                                               None         NaN
# 2750                                               None         NaN
# 2751                                             0-0-24         NaN
#
#       1_2122_vacancy  ...  1_2021_strength 2_2021_slot  2_2021_vacancy  \
# 0              500.0  ...             24.0           A           600.0
# 1              200.0  ...              NaN         NaN             NaN
# 2                NaN  ...            371.0           E           225.0
# 3              150.0  ...              NaN         NaN             NaN
# 4              300.0  ...            178.0         NaN             NaN
# ...              ...  ...              ...         ...             ...
# 2747             NaN  ...              NaN         NaN             NaN
# 2748             NaN  ...              NaN         NaN             NaN
# 2749             NaN  ...              NaN         NaN             NaN
# 2750             NaN  ...             13.0           P            50.0
# 2751             NaN  ...              NaN           P            50.0
#
#       2_2021_strength 1_1920_slot  1_1920_vacancy  1_1920_strength  \
# 0                 0.0           A           500.0            589.0
# 1                 NaN         NaN             NaN              NaN
# 2               149.0           E           350.0            307.0
# 3                 NaN           F           150.0             97.0
# 4                 NaN           D           150.0            153.0
# ...               ...         ...             ...              ...
# 2747              NaN         NaN             NaN              NaN
# 2748              NaN         NaN             NaN              NaN
# 2749              NaN         NaN             NaN              NaN
# 2750              0.0           P            60.0             23.0
# 2751             12.0           P            60.0              0.0
#
#      2_1920_slot  2_1920_vacancy  2_1920_strength
# 0              A           250.0            568.0
# 1            NaN             NaN              NaN
# 2              E           300.0            134.0
# 3            NaN             NaN              NaN
# 4            NaN             NaN              NaN
# ...          ...             ...              ...
# 2747         NaN             NaN              NaN
# 2748         NaN             NaN              NaN
# 2749         NaN             NaN              NaN
# 2750         NaN             NaN              NaN
# 2751           P            60.0             19.0
#
# [2752 rows x 26 columns]

# %%
pd.concat(g for _, g in df.groupby("code") if len(g) > 1)
# Out:
#         code                                  name credits credit-structure  \
# 564   COL106        Data Structures and Algorithms       5            3-0-4
# 565   COL106        Data Structures and Algorithms       5            3-0-4
# 325   CVL100                 Environmental Science       2            2-0-0
# 326   CVL100                 Environmental Science       2            2-0-0
# 327   CVL100                 Environmental Science       2            2-0-0
# ...      ...                                   ...     ...              ...
# 2743  SPL810     Advanced Topics in Policy Studies       3            3-0-0
# 2288  TXP222        Yarn Manufacture Laboratory-II       1            0-0-2
# 2289  TXP222        Yarn Manufacture Laboratory-II       1            0-0-2
# 2297  TXP242  Technology of Textile Coloration Lab       1            0-0-3
# 2298  TXP242  Technology of Textile Coloration Lab       1            0-0-3
#
#          pre-requisites overlap  \
# 564              COL100    None
# 565              COL100    None
# 325                None    None
# 326                None    None
# 327                None    None
# ...                 ...     ...
# 2743               None    None
# 2288             TXP221    None
# 2289             TXP221    None
# 2297  TXL241 and TXP241    None
# 2298  TXL241 and TXP241    None
#
#                                           department  \
# 564   Department of Computer Science and Engineering
# 565   Department of Computer Science and Engineering
# 325                          Department of Chemistry
# 326                          Department of Chemistry
# 327                          Department of Chemistry
# ...                                              ...
# 2743     Department of Textile and Fibre Engineering
# 2288     Department of Textile and Fibre Engineering
# 2289     Department of Textile and Fibre Engineering
# 2297     Department of Textile and Fibre Engineering
# 2298     Department of Textile and Fibre Engineering
#
#                                             description 1_2122_slot  \
# 564   Introduction to object-oriented programming th...           F
# 565   Introduction to object-oriented programming th...           F
# 325   Pollutant sources and control in air and water...           C
# 326   Pollutant sources and control in air and water...           C
# 327   Pollutant sources and control in air and water...           C
# ...                                                 ...         ...
# 2743  This course will introduce students to advance...         NaN
# 2288  Experiments related to the lecture course enti...           B
# 2289  Experiments related to the lecture course enti...           P
# 2297  The principles of dyeing and printing of texti...           E
# 2298  The principles of dyeing and printing of texti...           P
#
#       1_2122_vacancy  ...  1_2021_strength 2_2021_slot  2_2021_vacancy  \
# 564            405.0  ...            473.0           F           200.0
# 565            405.0  ...            473.0          AD           200.0
# 325            800.0  ...              1.0           C             0.0
# 326            800.0  ...              1.0          C1           250.0
# 327            800.0  ...              1.0          C2           260.0
# ...              ...  ...              ...         ...             ...
# 2743             NaN  ...              NaN          AC            35.0
# 2288           120.0  ...              NaN           P             0.0
# 2289             0.0  ...              NaN           P             0.0
# 2297           120.0  ...              NaN           P             0.0
# 2298             0.0  ...              NaN           P             0.0
#
#       2_2021_strength 1_1920_slot  1_1920_vacancy  1_1920_strength  \
# 564             199.0           F           180.0            373.0
# 565             202.0           F           180.0            373.0
# 325               0.0           C           500.0            529.0
# 326             308.0           C           500.0            529.0
# 327             302.0           C           500.0            529.0
# ...               ...         ...             ...              ...
# 2743              3.0         NaN             NaN              NaN
# 2288              0.0           B           120.0            117.0
# 2289              0.0           B           120.0            117.0
# 2297              0.0           E           120.0            111.0
# 2298              0.0           E           120.0            111.0
#
#      2_1920_slot  2_1920_vacancy  2_1920_strength
# 564            F           385.0            344.0
# 565            F           385.0            344.0
# 325            C           533.0            486.0
# 326            C           533.0            486.0
# 327            C           533.0            486.0
# ...          ...             ...              ...
# 2743         NaN             NaN              NaN
# 2288         NaN             NaN              NaN
# 2289         NaN             NaN              NaN
# 2297         NaN             NaN              NaN
# 2298         NaN             NaN              NaN
#
# [425 rows x 26 columns]

# %% [markdown]
# Naive bayes prediction: Say a course has historically been offered in two slots, A and B. The probability that the course is offered in slot A, given that it's offered is
# $$P\left(A|\text{Off}\right) = \frac{P(A)\cdot P(\text{Off}|A)}{P(Off)} = \frac{P(A)}{P(\text{Off})} = \frac{n(A)}{n(\text{Off})}$$
#
# This is easy enough to compute and predict for all courses.
#
# We'll need to do something different for years, though. First year cores alternate, while programme cores (CVL/SBL) are offered in every sem. Department cores generally alternate. DE's/PE's are the main targets of this. We can do a similar classification to the above for them.

# %%
#
# calculate the offering scores for the different courses.
# it's ok to do the list comprehension: not too bad a performance hit here.
#

for y in years:
    for i in [1,2]:
        sltdata = df[f'{i}_{y}_slot']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Arush Bansal\OneDrive - IIT Delhi\Desktop\DevClub\IIT_course_planner\slot_stats_infer.ipynb Cell 10 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> #
#       <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> # calculate the offering scores for the different courses.
#       <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> # it's ok to do the list comprehension: not too bad a performance hit here.
#       <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> #
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> for y in years:
#       <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a>     for i in [1,2]:
#       <a href='vscode-notebook-cell:/c%3A/Users/Arush%20Bansal/OneDrive%20-%20IIT%20Delhi/Desktop/DevClub/IIT_course_planner/slot_stats_infer.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>         sltdata = df[f'{i}_{y}_slot']
#
# NameError: name 'years' is not defined
